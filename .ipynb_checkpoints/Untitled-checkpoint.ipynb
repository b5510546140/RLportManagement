# %%
# Agent
import keras
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.optimizers import Adam

import numpy as np
import random
from collections import deque

class Agent:
    def __init__(self, state_size, is_eval=False, model_name=""):
        self.state_size = state_size # normalized previous days
        self.action_size = 5 #  buy_1, sell_1,DO Nothing, buy2, sell2
        self.memory = deque(maxlen=2000)
        self.inventory1 = []
        self.inventory2 = []
        self.model_name = model_name
        self.is_eval = is_eval
        self.gamma = 0.95 #gamma is the discount factor. It quantifies how much importance we give for future rewards.
        self.epsilon = 1.0 #Exploration and Exploitation — Epsilon (ε)
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = load_model("models/" + model_name) if is_eval else self._model()

    def _model(self):
        model = Sequential()
        model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        model.add(Dense(units=32, activation="relu"))
        model.add(Dense(units=8, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.compile(loss="mse", optimizer=Adam(lr=0.0001))
        return model

    def act(self, state):
        if not self.is_eval and random.random() <= self.epsilon:
            #print("random action")
            return random.randrange(self.action_size)
        #print("Calculating using model")
        options = self.model.predict(state)
        #print(str(options))
        return np.argmax(options[0])

    def expReplay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        
        minibatch = random.sample(self.memory, batch_size)
        
        for state, action, reward, next_state, done in mini_batch:
            target = reward
            
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
              
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import math

# prints formatted price
def formatPrice(n):
    return ("-$" if n < 0 else "$") + "{0:.2f}".format(abs(n))

# returns the vector containing stock data from a fixed file
def getStockDataVec(key):
    vec = []
    lines = open("data/" + key + ".txt", "r").read().splitlines()

    for line in lines[1:]:
        vec.append(float(line.split(",")[4]))

    return vec


# returns the vector containing stock data from a fixed file
def getStockVolVec(key):
    vol = []
    lines = open("data/" + key + ".txt", "r").read().splitlines()

    for line in lines[1:]:
        vol.append(float(line.split(",")[5]))

    return vol

# returns the sigmoid
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
# State
import numpy as np
import random
import math, random 
import gym 
import numpy as np 


class State:
    def __init__(self, data1, data2, Bal_stock1, Bal_stock2, open_cash, timestep):
        self.Stock1Price=data1[timestep] #stock 1 open price
        self.Stock2Price=data2[timestep] #stock 2 open price
        self.Stock1Blnc=Bal_stock1 #stock 1 balance
        self.Stock2Blnc=Bal_stock2 #stock 2 balance
        self.open_cash=open_cash #cash balance
        self.fiveday_stock1=self.five_day_window(data1, timestep)
        self.fiveday_stock2=self.five_day_window(data2, timestep)
        #self.volume1=volume1[timestep]
        #self.volume2=volume2[timestep]
        self.portfolio_value=self.portfolio_value()

    def portfolio_value(self):
        pvalue=0
        #print("In portfolio func")
        #print("self.Stock1Price",self.Stock1Price, type(self.Stock1Price))
        #print("self.Stock1Blnc",self.Stock1Blnc[0], type(self.Stock1Blnc))

        v1=self.Stock1Price * float(self.Stock1Blnc)
        v2=self.Stock2Price * float(self.Stock2Blnc)
        v3=float(self.open_cash)
        return (v1+v2+v3)
    
    def next_opening_price(self):
        return [data1[timestep+1], data2[timestep+1]]
    
    def five_day_window(self,data, timestep):
        step = timestep
        if step < 5:
            return data[0]
        
        stock_5days = np.mean(data[step-5:step])
        #print("stock_5days=" + str(stock_5days))
        #print(stock_5days)

        #print(type(stock_5days))

        return stock_5days
    
    def reset(self):
        #self.state = torch.FloatTensor(torch.zeros(8)).cuda()
        self.Stock1Price=151.25 #stock 1 open price Google
        self.Stock2Price=21.845 #stock 2 open price Walmart
        self.Stock1Blnc=34 #stock 1 balance Google
        self.Stock2Blnc=221 #stock 2 balance Walmart
        self.open_cash=10000 #cash balance
        self.fiveday_stock1=151.25
        self.fiveday_stock2=21.845
        self.portfolio_value=10000
        
    def getState(self):
        #print("In get state")
        res=[]
        res.append(self.Stock1Price) #stock 1 open price
        res.append(self.Stock2Price) #stock 2 open price
        res.append(self.Stock1Blnc) #stock 1 balance
        res.append(self.Stock2Blnc) #stock 2 balance
        res.append(self.open_cash) #cash balance
        res.append(self.fiveday_stock1)
        res.append(self.fiveday_stock2)        
        res.append(self.portfolio_value)
        #res.append(self.volume1)
        #res.append(self.volume2)


        
        #print(res)
        res1=np.array([res])
        #print("res array"+np.array([res]))
        return res1

# %%
import pandas as pd
import sys

import pandas as pd

import math, random 
import numpy as np 
from datetime import datetime, timedelta

#stock_name, window_size, episode_count = sys.argv[1], int(sys.argv[2]), int(sys.argv[3])

stock_name1,stock_name2, episode_count, start_balance, training, test = 'aapl.us','amzn.us', 51,10000,1500,500


pd_data1=pd.read_csv('data/aapl.us.txt', sep=",", header=0)
pd_data2=pd.read_csv('data/amzn.us.txt', sep=",", header=0)

# %%
if (pd_data1['Date'][0]>pd_data2['Date'][0]): 
    #print("Date1 is older than Date2")
    pd_data1=pd_data1[pd_data1.Date>=pd_data2['Date'][0]]
    pd_data1=pd_data1.reset_index(drop=True)
else:
    #print("Date2>Date1")
    pd_data2=pd_data2[pd_data2.Date>=pd_data1['Date'][0]]
    pd_data2=pd_data2.reset_index(drop=True)
    #print("Date2>Date1  and date2 is" + str(pd_data2['Date'][0]) +" Date 1 is : "+ str(pd_data1['Date'][0]))

# %%
# Pre -Processing the Datasheet ...Drop Data that is not in both stock data- some days data is missing in Apple and some in Amazon
import datetime
#timestamp = data1_date[10]
#print(timestamp.strftime('%Y-%m-%d'))
#Convert  Date to Date format
pd_data1['Date']=pd.to_datetime(pd_data1['Date'], format='%Y/%m/%d')
pd_data2['Date']=pd.to_datetime(pd_data2['Date'], format='%Y/%m/%d')

list1= pd_data1['Date']
list2= pd_data2['Date']
diff_pd1_data = list(set(list1) - set(list2))
diff_pd2_data = list(set(list2) - set(list1))
#x11=x[0].strftime('%Y-%m-%d 00:00:00')
#p=datetime.datetime.strptime(x11, "%Y-%m-%d 00:00:00")
#print(p)
for k in range(len(diff_pd1_data)):
    pd1_dat_format=diff_pd1_data[k].strftime('%Y-%m-%d 00:00:00')
    date_format_pd1=datetime.datetime.strptime(pd1_dat_format, "%Y-%m-%d 00:00:00")
    for i, j in enumerate(list1):
        if j == date_format_pd1:
            #print(i)
            pd_data1=pd_data1.drop([i])            
pd_data1=pd_data1.reset_index(drop=True)

for k in range(len(diff_pd2_data)):
    pd2_dat_format=diff_pd2_data[k].strftime('%Y-%m-%d 00:00:00')
    date_format_pd2=datetime.datetime.strptime(pd2_dat_format, "%Y-%m-%d 00:00:00")
    for M, N in enumerate(list2):
        if N == date_format_pd2:
            #print(M)
            pd_data2=pd_data2.drop([M])
            
pd_data2=pd_data2.reset_index(drop=True)

# %%
#Training Data
pd_data1_train=pd_data1[0:training]
pd_data2_train=pd_data2[0:training]
#Test Data
pd_data1_test=pd_data1[training:training+test]
pd_data2_test=pd_data2[training:training+test]



vol1_train=getStockVolVec(stock_name1)
vol2_train=getStockVolVec(stock_name2)

# %%
#Initialize state and set benchmarking model



total_Prof=[]
done=False


batch_size = 64

#Benchmark Model
#In this model, we would divide 


#Initialize state and set benchmarking model


#print(df_data1)
total_Prof=[]
done=False

Act_datasize = training
batch_size = 64

#Benchmark Model

data1_train=pd_data1_train['Open']
data2_train=pd_data2_train['Open']

data1_date=pd_data1_train['Date']

Act_Bench_Stock1_Bal=int(np.floor((start_balance/4)/data1_train[0]))
Act_Bench_Stock2_Bal=int(np.floor((start_balance/4)/data2_train[0]))
Act_Bench_Open_cash=start_balance/2




### Program to calculate benchmark profit


#sell 10% of stock in 10 intervals

interval=int(Act_datasize/10)
Total_Stock1_Amount= 0
Total_Stock2_Amount= 0
stocks2Value = 0
stocks1Value = 0

Act_stocks1=np.floor(Act_Bench_Stock1_Bal /10)
Act_stocks2=np.floor(Act_Bench_Stock2_Bal /10)
print(str(Act_stocks1))
print(str(Act_stocks2))

remaining_stock1=Act_Bench_Stock1_Bal
remaining_stock2=Act_Bench_Stock2_Bal
ttl=0

Benchmark_Port_Value=[]


for j in range (interval,Act_datasize+1,interval):
        #print("closing prices : " + str(data1_train[j-1]) )
        Price_closing_Stock1=data1_train[j-1]
        Price_closing_Stock2=data2_train[j-1]
        
        date_stock1=data1_date[j-1].strftime('%Y-%m-%d')
        #print(date_stock1)
                
        stocks1Value= Act_stocks1 * Price_closing_Stock1
        stocks2Value= Act_stocks2 * Price_closing_Stock2
        remaining_stock1=remaining_stock1-Act_stocks1
        remaining_stock2=remaining_stock2-Act_stocks2
        #print("J is:"+ str(j))
        
        
        
        Stock1_Port_value=remaining_stock1*Price_closing_Stock1
        Stock2_Port_value=remaining_stock2*Price_closing_Stock2
        Act_Bench_Open_cash=Act_Bench_Open_cash+stocks1Value+stocks2Value #Adding 10% sold value into open cash
        
        Total_Portfolio_value=Act_Bench_Open_cash+Stock1_Port_value+Stock2_Port_value
        Benchmark_Port_Value.append([date_stock1,Total_Portfolio_value])
        



#print ("total_Test_Benchmark_amount : " +  str(Total_Portfolio_value))

Training_Benchmark_Portfolio_Value= Total_Portfolio_value




print("Benchmark_Profit is  " + str(Training_Benchmark_Portfolio_Value) +"with Apple Stocks:  " + str(remaining_stock1) + 
      " and Amazon stocks:  "+ str(remaining_stock2) )


#Define arrays to store per episode values 
total_Prof=[]
total_stock1bal=[]
total_stock2bal=[]
total_open_cash=[]
total_port_value=[]
total_days_played=[]
# Out:
# 445.0
# 126.0
# Benchmark_Profit is  52655.37275with Apple Stocks:  6.0 and Amazon stocks:  9.0

# %%
#Training run

import csv


for e in range(episode_count + 1):
    print("..........")
    print("Episode " + str(e) + "/" + str(episode_count))
    
    Bal_stock1=int(np.floor((start_balance/4)/data1_train[0]))
    Bal_stock2=int(np.floor((start_balance/4)/data2_train[0]))
    open_cash=start_balance/2
    
    datasize=training
    done=False
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent = Agent(8)
    agent.inventory1 =[]
    agent.inventory2 =[]
    for i in range(Bal_stock1):
        agent.inventory1.append(data1_train[0])
    for i in range(Bal_stock2):
        agent.inventory2.append(data2_train[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    #timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(datasize):
#         print(datasize)
        #print(pd_data1_train.iloc[t,0])
        state_class_obj= State(data1_train, data2_train, Bal_stock1, Bal_stock2, open_cash,t)
        state_array_obj=state_class_obj.getState()
        action = agent.act(state_array_obj)
         
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent.inventory1.append(data1_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                #needs to be reviewed
                
                if(state_class_obj.open_cash<500):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:  
                    reward=-change_percent_stock1*100
                

               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                reward=-200000
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                bought_price1=agent.inventory1.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                if(state_class_obj.Stock1Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock1)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock1*100 #State[0] is the price of stock 1. Here we are buying 1 stock
                
                #total_profit += data1_train[t] - bought_price1
            #print("reward for sell stock1 " + str(reward))
                
        


        
        if action == 2:             # Do nothing action    
                if (abs(change_percent_stock1)<=2) and (abs(change_percent_stock2)<=2):
                    reward=10000
                elif (state_class_obj.open_cash<0.1*start_balance):
                    reward=1000000
                elif (abs(change_percent_stock1)<=2) or (abs(change_percent_stock2)<=2):
                    reward=1000
                else:
                    reward=-100000
                
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=open_cash
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
                reward=-200000
                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_train[t])
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash-state_class_obj.Stock2Price
                
                if(state_class_obj.open_cash<5000):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=-change_percent_stock2*100
 
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    reward=-200000
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                bought_price2=agent.inventory2.pop(0)
                Bal_stock1_t1= len(agent.inventory1)
                Bal_stock2_t1=len(agent.inventory2)
                open_cash_t1=state_class_obj.open_cash+state_class_obj.Stock2Price
    
              
                if(state_class_obj.Stock2Blnc<10):
                    reward=-100000
                elif (abs(change_percent_stock2)<=2):
                    reward=-10000
                else:
                    reward=change_percent_stock2*100 
                
                
                total_profit += state_class_obj.Stock2Price - bought_price2

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            next_state_class_obj=State(data1_train, data2_train, Bal_stock1_t1, Bal_stock2_t1, open_cash_t1,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        agent.memory.append((state_array_obj, action, reward, next_state_array_obj, done))
        #print("Action is "+str(action)+" reward is" + str(reward))
         
        Bal_stock1=Bal_stock1_t1
        Bal_stock2= Bal_stock2_t1
        open_cash=open_cash_t1
        
        
      #  print("total_profit on day basis " + str(total_profit) +"on day"+str(t) + "stock 1 number: " + 
        #      str(len(agent.inventory1))+"/"+str(next_state_class_obj.Stock1Blnc)+" stock2 number:"+
         #         str(len(agent.inventory2)) +"/"+str(next_state_class_obj.Stock2Blnc)+
          #        "open cash: "+str(next_state_class_obj.open_cash))
        
       # print("doneAction" + str(done))
       # print("--------------------------------") 
       
        
        
        if done==True:
            #print("--------------------------------")
           # print("Total Profit: " + formatPrice(total_profit))
           # print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(datasize))
           # print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
             #     "  stock 1 number: " + str(len(agent.inventory1))
            #      +"  stock 2 number: "+str(len(agent.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            total_Prof.append(total_profit)
            total_stock1bal.append(len(agent.inventory1))
            total_stock2bal.append(len(agent.inventory2))
            total_open_cash.append(state_class_obj.open_cash)
            total_port_value.append(state_class_obj.portfolio_value)
            total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
           
          

        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size)


    if e % 10 == 0:
        agent.model.save("models/model_ep" + str(e))
        

        
#print("Total Apple stocks in episodes"+ str(total_stock1bal))
#print("Total Amazon stocks in episodes"+ str(total_stock2bal))
#print("Total Open cash in episodes"+ str(total_open_cash))
#print("Total Portfolio value in episodes"+ str(total_port_value))
#print("Total Days in episodes"+ str(total_days_played))
#print("Benchmark_Profit is  " + str(int(Benchmark_Portfolio_Value)) +"   with Apple Stocks: " + str(Bench_Stock1_Bal) + 
    #  "   and Amazon stocks: "+ str(Bench_Stock2_Bal) )
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0830 15:29:45.263429 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0830 15:29:45.280246 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0830 15:29:45.284106 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0830 15:29:45.351316 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# ..........
# Episode 0/51
# W0830 15:29:45.480289 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0830 15:29:45.481665 4782798272 deprecation_wrapper.py:119] From /Users/watwattanagaroon/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# --------------------------------
# ..........
# Episode 1/51
# --------------------------------
# ..........
# Episode 2/51
# --------------------------------
# ..........
# Episode 3/51
# --------------------------------
# ..........
# Episode 4/51
# --------------------------------
# ..........
# Episode 5/51
# --------------------------------
# ..........
# Episode 6/51
# --------------------------------
# ..........
# Episode 7/51
# --------------------------------
# ..........
# Episode 8/51
# --------------------------------
# ..........
# Episode 9/51
# --------------------------------
# ..........
# Episode 10/51
# --------------------------------
# ..........
# Episode 11/51
# --------------------------------
# ..........
# Episode 12/51
# --------------------------------
# ..........
# Episode 13/51
# --------------------------------
# ..........
# Episode 14/51
# --------------------------------
# ..........
# Episode 15/51
# --------------------------------
# ..........
# Episode 16/51
# --------------------------------
# ..........
# Episode 17/51
# --------------------------------
# ..........
# Episode 18/51
# --------------------------------
# ..........
# Episode 19/51
# --------------------------------
# ..........
# Episode 20/51
# --------------------------------
# ..........
# Episode 21/51
# --------------------------------
# ..........
# Episode 22/51
# --------------------------------
# ..........
# Episode 23/51
# --------------------------------
# ..........
# Episode 24/51
# --------------------------------
# ..........
# Episode 25/51
# --------------------------------
# ..........
# Episode 26/51
# --------------------------------
# ..........
# Episode 27/51
# --------------------------------
# ..........
# Episode 28/51
# --------------------------------
# ..........
# Episode 29/51
# --------------------------------
# ..........
# Episode 30/51
# --------------------------------
# ..........
# Episode 31/51
# --------------------------------
# ..........
# Episode 32/51
# --------------------------------
# ..........
# Episode 33/51
# --------------------------------
# ..........
# Episode 34/51
# --------------------------------
# ..........
# Episode 35/51
# --------------------------------
# ..........
# Episode 36/51
# --------------------------------
# ..........
# Episode 37/51
# --------------------------------
# ..........
# Episode 38/51
# --------------------------------
# ..........
# Episode 39/51
# --------------------------------
# ..........
# Episode 40/51
# --------------------------------
# ..........
# Episode 41/51
# --------------------------------
# ..........
# Episode 42/51
# --------------------------------
# ..........
# Episode 43/51
# --------------------------------
# ..........
# Episode 44/51
# --------------------------------
# ..........
# Episode 45/51
# --------------------------------
# ..........
# Episode 46/51
# --------------------------------
# ..........
# Episode 47/51
# --------------------------------
# ..........
# Episode 48/51
# --------------------------------
# ..........
# Episode 49/51
# --------------------------------
# ..........
# Episode 50/51
# --------------------------------
# ..........
# Episode 51/51
# --------------------------------

# %%
print("Total Apple stocks in episodes"+ str(total_stock1bal))
print("///////")
print("Total Amazon stocks in episodes"+ str(total_stock2bal))
print("Total Open cash in episodes"+ str(total_open_cash))
print("Total Portfolio value in episodes"+ str(total_port_value))
print("Total Days in episodes"+ str(total_days_played))

print("Benchmark_Profit is  " + str(int(Training_Benchmark_Portfolio_Value)) +"   with remaining Apple Stocks: " + str(remaining_stock1) + 
      "   and remaining Amazon stocks: "+ str(remaining_stock2) )
# Out:
# Total Apple stocks in episodes[4346, 3217, 4462, 5310, 5700, 5677, 4469, 4455, 4446, 4558, 3243, 4018, 4438, 4446, 4442, 4450, 4456, 4453, 4851, 5689, 4472, 4466, 3245, 5210, 5681, 5551, 5695, 4460, 3249, 5670, 4488, 4453, 4441, 5698, 5656, 4896, 4453, 5697, 3221, 4465, 5685, 3349, 4465, 4454, 5687, 5535, 3220, 4459, 4453, 3794, 4465, 4468]
# ///////
# Total Amazon stocks in episodes[1264, 1277, 43, 911, 1261, 1284, 274, 1484, 30, 1361, 1287, 479, 1475, 29, 1274, 1269, 1275, 18, 1252, 1273, 1283, 1264, 1223, 1264, 1279, 1280, 1255, 1481, 1265, 1256, 1264, 1482, 1477, 1283, 1278, 481, 11, 1284, 1257, 1492, 1281, 1284, 1491, 1501, 1277, 1268, 1270, 1263, 30, 715, 1492, 1325]
# Total Open cash in episodes[5333.291810000002, 6701.97519, 43788.40853999997, 24742.226730000002, 2988.598279999994, 2921.895719999999, 40708.674689999956, 11.206079999999105, 44282.50768999996, 23678.674299999955, 6910.975869999999, 18717.616259999988, 4.497980000006407, 44772.49294999997, 4954.75045, 5084.527979999996, 4850.395109999999, 44710.49632999997, 3758.7029400000088, 3000.85212, 4971.306230000007, 5125.892129999996, 6966.376049999994, 3323.8688399999996, 2955.242039999992, 2858.705579999992, 3714.163949999995, 29.695670000002963, 6806.909410000004, 2998.296639999995, 5112.926830000008, 8.493700000000615, 36.061729999997965, 2478.7008199999955, 2822.857969999993, 36918.40837000008, 44227.61332999998, 2936.5356500000034, 7302.7011999999995, 61.42055000000789, 2825.137430000003, 6774.217099999999, 18.318550000001203, 25.569260000009365, 2379.440020000002, 3122.279470000003, 7107.612419999996, 5115.718430000001, 44390.88102999996, 34911.803289999945, 22.035110000007755, 54.35852999999817]
# Total Portfolio value in episodes[52459.18181, 52899.44519, 50623.27853999997, 61330.111730000004, 51645.43327999999, 52313.235720000004, 55207.31968999996, 96798.65008, 50667.27768999996, 74307.74429999996, 53471.17587, 39466.50625999999, 101957.14178, 51124.12294999997, 52527.72045, 52501.43798, 52473.37511, 50706.021329999974, 51095.43794000001, 52042.112120000005, 52878.686230000014, 52396.38212999999, 51408.02604999999, 51489.67384, 52185.70203999999, 51965.65557999999, 52166.133949999996, 94701.90166999999, 52645.25941, 51453.281639999994, 52409.92683000001, 104492.9909, 94445.16983, 51862.20582, 51990.05296999999, 58791.56837000008, 49991.15832999998, 52351.97565000001, 52842.1912, 99839.05405000002, 52126.69743000001, 53362.727100000004, 99676.63304999999, 81729.66886, 51550.85002, 51812.26947000001, 53076.71742, 52344.63343, 50784.08602999996, 63211.81328999995, 99743.84961, 97632.92612999999]
# Total Days in episodes[1499, 1499, 1499, 1499, 1499, 1499, 1499, 451, 1499, 1499, 1499, 1499, 461, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 1499, 454, 1499, 1499, 1499, 450, 454, 1499, 1499, 1499, 1499, 1499, 1499, 448, 1499, 1499, 449, 444, 1499, 1499, 1499, 1499, 1499, 1499, 449, 468]
# Benchmark_Profit is  52655   with remaining Apple Stocks: 6.0   and remaining Amazon stocks: 9.0

# %%
#Actual run

import csv
episode_count=0


#Define arrays to store per episode values 
Act_total_Prof=[]
Act_total_stock1bal=[]
Act_total_stock2bal=[]
Act_total_open_cash=[]
Act_total_port_value=[]
Act_total_days_played=[]
actions_done_perday=[]
portfolio_value=[]

# Take Opening price in a new variable
pd_data1_test=pd_data1_test.reset_index(drop=True)
pd_data2_test=pd_data2_test.reset_index(drop=True)
data1_test=pd_data1_test['Close']
data2_test=pd_data2_test['Close']

data1_date=pd_data1_test['Date']
Act_datasize = test

from keras.models import load_model

model_name='model_ep50'

model = load_model("models/" + model_name)

initial_cash = state_class_obj.portfolio_value
print(initial_cash)

for e in range(1): #here we run only for 1 episode, as it is Test run

    Bal_stock1_t2=Act_Bench_Stock1_Bal
    Bal_stock2_t2=Act_Bench_Stock2_Bal
    done=False
    open_cash_t2= Act_Bench_Open_cash  
    total_profit = 0
    reward = 0
    
    #Initialize Agent
    agent_test = Agent(8, is_eval=True, model_name=model_name)
    #agent = Agent(8)

    agent_test.inventory1 =[]
    agent_test.inventory2 =[]
    for i in range(Bal_stock1_t2):
        agent_test.inventory1.append(data1_test[0])
    for i in range(Bal_stock2_t2):
        agent_test.inventory2.append(data2_test[0]) 
    
    
    #Timestep delta to make sure that with time reward increases for taking action
    timestep_delta=0
    
    #Running episode over all days in the datasize
    for t in range(Act_datasize):
        print("..........")
        
        print(pd_data1_test.iloc[t,0])
        state_class_obj= State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
        state_array_obj=state_class_obj.getState()
        action = agent_test.act(state_array_obj)
        
        print("Total portfolio value: " + str(state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(state_class_obj.open_cash))


        
        #reward should be more as time goes further. We will remove reward_timedelta from actual reward 
        #reward_timedelta=(datasize-t)*timestep_delta
        
                   
        change_percent_stock1=(state_class_obj.Stock1Price-state_class_obj.fiveday_stock1)/state_class_obj.fiveday_stock1*100
        change_percent_stock2=(state_class_obj.Stock2Price-state_class_obj.fiveday_stock2)/state_class_obj.fiveday_stock2*100
        
        #print("change_percent_stock1:  "+str(change_percent_stock1))
        #print("change_percent_stock2:  "+str(change_percent_stock2))
        
        
        if action == 0:  #buy stock 1
            if state_class_obj.Stock1Price > state_class_obj.open_cash:
                '''
                print("Buy stock 1 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")
              
                done = True
                #end episode
                     
            else:
                #print("In Buy stock 1")
                agent_test.inventory1.append(data1_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock1Price #Here we are buying 1 stock
                
                
               
                
        if action == 1:  #sell stock 1
            if state_class_obj.Stock1Blnc <1 :
               # print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                
                done = True
                #end episode
            else:
                #print("In sell stock 1")
                agent_test.inventory1.pop(0)

                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock1Price #State[0] is the price of stock 1. Here we are buying 1 stoc
          
                 
        


        
        if action == 2:             # Do nothing action    
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
               # print("Do nothing")
        
        
        if action == 3:  #buy stock 2
            if state_class_obj.Stock2Price > state_class_obj.open_cash:
                '''
                print("Buy stock 2 when it did not have cash, so bankrupt, end of episode")
                reward=-reward_timedelta*10
                done = True
                
                '''
                #If agent is trying to buy when it has no cash but has stock1 and stock2 balance then, 
                #it should pick from other actions
                #if (state_class_obj.Stock1Blnc>1) and  (state_class_obj.Stock2Blnc>1):
                 #   action=random.sample([1, 2, 4, 5, 6],  1)  # Choose 1 elements from sell actions
                #else:    
                #print("Bankrupt")

                done = True
                     #end episode   
            else:
                #print("In Buy stock 2")
                agent.inventory2.append(data2_test[t])
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash-state_class_obj.Stock2Price
                
              
        
        if action == 4:  #sell stock 2
            if state_class_obj.Stock2Blnc <1 :
                    #print("sold stock 2 when it did not have stock 2, so bankrupt, end of episode")
                    done = True
                #end episode
            else:
                #print("In sell stock 2")
                agent_test.inventory2.pop(0)
                Bal_stock1_t2= len(agent_test.inventory1)
                Bal_stock2_t2=len(agent_test.inventory2)
                open_cash_t2=state_class_obj.open_cash+state_class_obj.Stock2Price
    

               # print("reward for selling stock2: " + str(reward))
            
        
        
        #print("reward:  "+str(reward))
        #if done!= False:done = True if t == datasize
        if t == Act_datasize-1:
            #print("t==datasize")
            done=True
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t)
            next_state_array_obj=next_state_class_obj.getState()
        else:
            #print("t!=datasize"+str(open_cash_t2))
            next_state_class_obj=State(data1_test, data2_test, Bal_stock1_t2, Bal_stock2_t2, open_cash_t2,t+1)
            next_state_array_obj=next_state_class_obj.getState()
            
        #print("Action is "+str(action)+" reward is" + str(reward))


       
        
        actions_done_perday.append(action)
        portfolio_value.append(next_state_class_obj.portfolio_value)

        if done==True:
            print("--------------------------------")
            print("Total Profit: " + formatPrice(next_state_class_obj.portfolio_value - initial_cash))
            print("Total No. of days played: " + str(t)+ "  out of overall days:  " + str(Act_datasize))
            print("Total portfolio value: " + str(next_state_class_obj.portfolio_value)+ 
                  "  stock 1 number: " + str(len(agent_test.inventory1))
                   +"  stock 2 number: "+str(len(agent_test.inventory2))+"  open cash"+str(next_state_class_obj.open_cash))

            Act_total_Prof.append(total_profit)
            Act_total_stock1bal.append(len(agent_test.inventory1))
            Act_total_stock2bal.append(len(agent_test.inventory2))
            Act_total_open_cash.append(state_class_obj.open_cash)
            Act_total_port_value.append(state_class_obj.portfolio_value)
            Act_total_days_played.append(t)


            print("--------------------------------")
            state_class_obj.reset()
            break
# Out:
# 10000
# ..........
# 2003-05-15 00:00:00
# Total portfolio value: 99104.10715  stock 1 number: 4456  stock 2 number: 1269  open cash52349.88275
# ..........
# 2003-05-16 00:00:00
# Total portfolio value: 99621.38995  stock 1 number: 4456  stock 2 number: 1269  open cash52317.25275
# ..........
# 2003-05-19 00:00:00
# Total portfolio value: 97497.90114999999  stock 1 number: 4456  stock 2 number: 1269  open cash52284.20275
# ..........
# 2003-05-20 00:00:00
# Total portfolio value: 97273.91875000001  stock 1 number: 4456  stock 2 number: 1269  open cash52252.64275
# ..........
# 2003-05-21 00:00:00
# Total portfolio value: 97608.23994999999  stock 1 number: 4456  stock 2 number: 1269  open cash52221.162749999996
# ..........
# 2003-05-22 00:00:00
# Total portfolio value: 99270.57514999999  stock 1 number: 4456  stock 2 number: 1269  open cash52189.412749999996
# ..........
# 2003-05-23 00:00:00
# Total portfolio value: 98905.42635  stock 1 number: 4456  stock 2 number: 1269  open cash52156.412749999996
# ..........
# 2003-05-27 00:00:00
# Total portfolio value: 101735.20115  stock 1 number: 4456  stock 2 number: 1269  open cash52123.692749999995
# ..........
# 2003-05-28 00:00:00
# Total portfolio value: 101541.48515  stock 1 number: 4456  stock 2 number: 1269  open cash52088.842749999996
# ..........
# 2003-05-29 00:00:00
# Total portfolio value: 102330.99114999999  stock 1 number: 4456  stock 2 number: 1269  open cash52053.982749999996
# ..........
# 2003-05-30 00:00:00
# Total portfolio value: 102681.44995  stock 1 number: 4456  stock 2 number: 1269  open cash52018.43274999999
# ..........
# 2003-06-02 00:00:00
# Total portfolio value: 101855.77794999999  stock 1 number: 4456  stock 2 number: 1269  open cash51982.54274999999
# ..........
# 2003-06-03 00:00:00
# Total portfolio value: 101590.38954999999  stock 1 number: 4456  stock 2 number: 1269  open cash51947.162749999996
# ..........
# 2003-06-04 00:00:00
# Total portfolio value: 101844.20035  stock 1 number: 4456  stock 2 number: 1269  open cash51911.93274999999
# ..........
# 2003-06-05 00:00:00
# Total portfolio value: 101984.02914999999  stock 1 number: 4456  stock 2 number: 1269  open cash51876.54274999999
# ..........
# 2003-06-06 00:00:00
# Total portfolio value: 99052.18715  stock 1 number: 4456  stock 2 number: 1269  open cash51841.02275
# ..........
# 2003-06-09 00:00:00
# Total portfolio value: 99335.11915  stock 1 number: 4456  stock 2 number: 1269  open cash51807.67275
# ..........
# 2003-06-10 00:00:00
# Total portfolio value: 99910.42275  stock 1 number: 4456  stock 2 number: 1269  open cash51773.99275
# ..........
# 2003-06-11 00:00:00
# Total portfolio value: 100686.78795  stock 1 number: 4456  stock 2 number: 1269  open cash51739.92275
# ..........
# 2003-06-12 00:00:00
# Total portfolio value: 101440.99035000001  stock 1 number: 4456  stock 2 number: 1269  open cash51705.27275
# ..........
# 2003-06-13 00:00:00
# Total portfolio value: 99950.81955  stock 1 number: 4456  stock 2 number: 1269  open cash51670.07275
# ..........
# 2003-06-16 00:00:00
# Total portfolio value: 102326.41235  stock 1 number: 4456  stock 2 number: 1269  open cash51635.94275
# ..........
# 2003-06-17 00:00:00
# Total portfolio value: 102274.53075  stock 1 number: 4456  stock 2 number: 1269  open cash51600.102750000005
# ..........
# 2003-06-18 00:00:00
# Total portfolio value: 102512.50235000001  stock 1 number: 4456  stock 2 number: 1269  open cash51564.26275000001
# ..........
# 2003-06-19 00:00:00
# Total portfolio value: 102038.29515000002  stock 1 number: 4456  stock 2 number: 1269  open cash51528.41275000001
# ..........
# 2003-06-20 00:00:00
# Total portfolio value: 101436.87915000002  stock 1 number: 4456  stock 2 number: 1269  open cash51492.91275000001
# ..........
# 2003-06-23 00:00:00
# Total portfolio value: 102046.99515  stock 1 number: 4456  stock 2 number: 1269  open cash51457.87275000001
# ..........
# 2003-06-24 00:00:00
# Total portfolio value: 101703.67835  stock 1 number: 4456  stock 2 number: 1269  open cash51422.29275000001
# ..........
# 2003-06-25 00:00:00
# Total portfolio value: 101740.69795  stock 1 number: 4456  stock 2 number: 1269  open cash51386.892750000006
# ..........
# 2003-06-26 00:00:00
# Total portfolio value: 103451.00595  stock 1 number: 4456  stock 2 number: 1269  open cash51351.50275000001
# ..........
# 2003-06-27 00:00:00
# Total portfolio value: 102726.23715  stock 1 number: 4456  stock 2 number: 1269  open cash51314.782750000006
# ..........
# 2003-06-30 00:00:00
# Total portfolio value: 102806.66515000002  stock 1 number: 4456  stock 2 number: 1269  open cash51278.48275
# ..........
# 2003-07-01 00:00:00
# Total portfolio value: 103956.30795  stock 1 number: 4456  stock 2 number: 1269  open cash51242.16275
# ..........
# 2003-07-02 00:00:00
# Total portfolio value: 104732.59315  stock 1 number: 4456  stock 2 number: 1269  open cash51204.91275
# ..........
# 2003-07-03 00:00:00
# Total portfolio value: 104437.57235  stock 1 number: 4456  stock 2 number: 1269  open cash51167.062750000005
# ..........
# 2003-07-07 00:00:00
# Total portfolio value: 106356.32075  stock 1 number: 4456  stock 2 number: 1269  open cash51129.382750000004
# ..........
# 2003-07-08 00:00:00
# Total portfolio value: 108319.28675  stock 1 number: 4456  stock 2 number: 1269  open cash51090.33275
# ..........
# 2003-07-09 00:00:00
# Total portfolio value: 108122.60355  stock 1 number: 4456  stock 2 number: 1269  open cash51049.82275
# ..........
# 2003-07-10 00:00:00
# Total portfolio value: 105136.39675  stock 1 number: 4456  stock 2 number: 1269  open cash51009.32275
# ..........
# 2003-07-11 00:00:00
# Total portfolio value: 104415.61795  stock 1 number: 4456  stock 2 number: 1269  open cash50971.07275
# ..........
# 2003-07-14 00:00:00
# Total portfolio value: 106445.33355000001  stock 1 number: 4456  stock 2 number: 1269  open cash50933.42275
# ..........
# 2003-07-15 00:00:00
# Total portfolio value: 105255.43955000001  stock 1 number: 4456  stock 2 number: 1269  open cash50894.15275
# ..........
# 2003-07-16 00:00:00
# Total portfolio value: 104344.13075  stock 1 number: 4456  stock 2 number: 1269  open cash50855.72275
# ..........
# 2003-07-17 00:00:00
# Total portfolio value: 102934.14635  stock 1 number: 4456  stock 2 number: 1269  open cash50818.04275
# ..........
# 2003-07-18 00:00:00
# Total portfolio value: 101122.72634999998  stock 1 number: 4456  stock 2 number: 1269  open cash50781.67275
# ..........
# 2003-07-21 00:00:00
# Total portfolio value: 101457.92674999998  stock 1 number: 4456  stock 2 number: 1269  open cash50746.692749999995
# ..........
# 2003-07-22 00:00:00
# Total portfolio value: 100896.78474999999  stock 1 number: 4456  stock 2 number: 1269  open cash50711.36274999999
# ..........
# 2003-07-23 00:00:00
# Total portfolio value: 107505.68194999998  stock 1 number: 4456  stock 2 number: 1269  open cash50676.49274999999
# ..........
# 2003-07-24 00:00:00
# Total portfolio value: 108912.61995  stock 1 number: 4456  stock 2 number: 1269  open cash50636.38274999999
# ..........
# 2003-07-25 00:00:00
# Total portfolio value: 109532.52475  stock 1 number: 4456  stock 2 number: 1269  open cash50595.07274999999
# ..........
# 2003-07-28 00:00:00
# Total portfolio value: 109939.18315  stock 1 number: 4456  stock 2 number: 1269  open cash50553.47274999999
# ..........
# 2003-07-29 00:00:00
# Total portfolio value: 108947.96914999999  stock 1 number: 4456  stock 2 number: 1269  open cash50511.39274999999
# ..........
# 2003-07-30 00:00:00
# Total portfolio value: 107980.55875  stock 1 number: 4456  stock 2 number: 1269  open cash50470.00274999999
# ..........
# 2003-07-31 00:00:00
# Total portfolio value: 109285.55715  stock 1 number: 4456  stock 2 number: 1269  open cash50429.24274999999
# ..........
# 2003-08-01 00:00:00
# Total portfolio value: 107104.13194999998  stock 1 number: 4456  stock 2 number: 1269  open cash50387.60274999999
# ..........
# 2003-08-04 00:00:00
# Total portfolio value: 106717.78994999999  stock 1 number: 4456  stock 2 number: 1269  open cash50347.57274999999
# ..........
# 2003-08-05 00:00:00
# Total portfolio value: 105372.89275  stock 1 number: 4456  stock 2 number: 1269  open cash50307.92274999999
# ..........
# 2003-08-06 00:00:00
# Total portfolio value: 105281.59995  stock 1 number: 4456  stock 2 number: 1269  open cash50269.11274999999
# ..........
# 2003-08-07 00:00:00
# Total portfolio value: 105417.04514999999  stock 1 number: 4456  stock 2 number: 1269  open cash50230.17274999999
# ..........
# 2003-08-08 00:00:00
# Total portfolio value: 105475.93274999998  stock 1 number: 4456  stock 2 number: 1269  open cash50191.16274999999
# ..........
# 2003-08-11 00:00:00
# Total portfolio value: 105163.39554999999  stock 1 number: 4456  stock 2 number: 1269  open cash50152.01274999999
# ..........
# 2003-08-12 00:00:00
# Total portfolio value: 106303.53115  stock 1 number: 4456  stock 2 number: 1269  open cash50113.08274999999
# ..........
# 2003-08-13 00:00:00
# Total portfolio value: 106857.76594999999  stock 1 number: 4456  stock 2 number: 1269  open cash50073.23274999999
# ..........
# 2003-08-14 00:00:00
# Total portfolio value: 106868.49074999998  stock 1 number: 4456  stock 2 number: 1269  open cash50033.02274999999
# ..........
# 2003-08-15 00:00:00
# Total portfolio value: 106512.00674999999  stock 1 number: 4456  stock 2 number: 1269  open cash49992.722749999986
# ..........
# 2003-08-18 00:00:00
# Total portfolio value: 110348.94274999999  stock 1 number: 4456  stock 2 number: 1269  open cash49952.62274999999
# ..........
# 2003-08-19 00:00:00
# Total portfolio value: 110997.63435  stock 1 number: 4456  stock 2 number: 1269  open cash49909.60274999999
# ..........
# 2003-08-20 00:00:00
# Total portfolio value: 111395.24874999998  stock 1 number: 4456  stock 2 number: 1269  open cash49866.03274999999
# ..........
# 2003-08-21 00:00:00
# Total portfolio value: 114000.05515  stock 1 number: 4456  stock 2 number: 1269  open cash49822.27274999999
# ..........
# 2003-08-22 00:00:00
# Total portfolio value: 113116.64235  stock 1 number: 4456  stock 2 number: 1269  open cash49776.57274999999
# ..........
# 2003-08-25 00:00:00
# Total portfolio value: 113953.71634999999  stock 1 number: 4456  stock 2 number: 1269  open cash49731.35274999999
# ..........
# 2003-08-26 00:00:00
# Total portfolio value: 113979.97434999999  stock 1 number: 4456  stock 2 number: 1269  open cash49685.44274999999
# ..........
# 2003-08-27 00:00:00
# Total portfolio value: 113990.90634999999  stock 1 number: 4456  stock 2 number: 1269  open cash49639.51274999999
# ..........
# 2003-08-28 00:00:00
# Total portfolio value: 114226.14234999998  stock 1 number: 4456  stock 2 number: 1269  open cash49593.63274999999
# ..........
# 2003-08-29 00:00:00
# Total portfolio value: 114777.38715  stock 1 number: 4456  stock 2 number: 1269  open cash49547.69274999999
# ..........
# 2003-09-02 00:00:00
# Total portfolio value: 116085.38994999998  stock 1 number: 4456  stock 2 number: 1269  open cash49501.37274999999
# ..........
# 2003-09-03 00:00:00
# Total portfolio value: 114615.46234999999  stock 1 number: 4456  stock 2 number: 1269  open cash49454.042749999986
# ..........
# 2003-09-04 00:00:00
# Total portfolio value: 115929.52434999999  stock 1 number: 4456  stock 2 number: 1269  open cash49407.852749999984
# ..........
# 2003-09-05 00:00:00
# Total portfolio value: 114813.75634999998  stock 1 number: 4456  stock 2 number: 1269  open cash49360.56274999998
# ..........
# 2003-09-08 00:00:00
# Total portfolio value: 115799.40754999997  stock 1 number: 4456  stock 2 number: 1269  open cash49314.042749999986
# ..........
# 2003-09-09 00:00:00
# Total portfolio value: 114887.79394999999  stock 1 number: 4456  stock 2 number: 1269  open cash49266.76274999999
# ..........
# 2003-09-10 00:00:00
# Total portfolio value: 114201.67395  stock 1 number: 4456  stock 2 number: 1269  open cash49220.08274999999
# ..........
# 2003-09-11 00:00:00
# Total portfolio value: 112843.79155  stock 1 number: 4456  stock 2 number: 1269  open cash49173.862749999986
# ..........
# 2003-09-12 00:00:00
# Total portfolio value: 113687.10674999998  stock 1 number: 4456  stock 2 number: 1269  open cash49128.76274999999
# ..........
# 2003-09-15 00:00:00
# Total portfolio value: 113175.71514999997  stock 1 number: 4456  stock 2 number: 1269  open cash49083.08274999999
# ..........
# 2003-09-16 00:00:00
# Total portfolio value: 114095.34234999999  stock 1 number: 4456  stock 2 number: 1269  open cash49037.572749999985
# ..........
# 2003-09-17 00:00:00
# Total portfolio value: 113878.95994999999  stock 1 number: 4456  stock 2 number: 1269  open cash48991.33274999999
# ..........
# 2003-09-18 00:00:00
# Total portfolio value: 116284.13834999998  stock 1 number: 4456  stock 2 number: 1269  open cash48945.17274999998
# ..........
# 2003-09-19 00:00:00
# Total portfolio value: 115720.09434999998  stock 1 number: 4456  stock 2 number: 1269  open cash48897.252749999985
# ..........
# 2003-09-22 00:00:00
# Total portfolio value: 115388.10434999998  stock 1 number: 4456  stock 2 number: 1269  open cash48849.67274999998
# ..........
# 2003-09-23 00:00:00
# Total portfolio value: 119219.39514999998  stock 1 number: 4456  stock 2 number: 1269  open cash48802.20274999998
# ..........
# 2003-09-24 00:00:00
# Total portfolio value: 117789.28274999998  stock 1 number: 4456  stock 2 number: 1269  open cash48751.752749999985
# ..........
# 2003-09-25 00:00:00
# Total portfolio value: 118041.81274999998  stock 1 number: 4456  stock 2 number: 1269  open cash48702.142749999985
# ..........
# 2003-09-26 00:00:00
# Total portfolio value: 116181.16074999998  stock 1 number: 4456  stock 2 number: 1269  open cash48652.09274999998
# ..........
# 2003-09-29 00:00:00
# Total portfolio value: 117952.96554999998  stock 1 number: 4456  stock 2 number: 1269  open cash48603.532749999984
# ..........
# 2003-09-30 00:00:00
# Total portfolio value: 115924.00914999998  stock 1 number: 4456  stock 2 number: 1269  open cash48553.67274999998
# ..........
# 2003-10-01 00:00:00
# Total portfolio value: 116768.12194999997  stock 1 number: 4456  stock 2 number: 1269  open cash48505.24274999998
# ..........
# 2003-10-02 00:00:00
# Total portfolio value: 117891.55834999999  stock 1 number: 4456  stock 2 number: 1269  open cash48456.12274999998
# ..........
# 2003-10-03 00:00:00
# Total portfolio value: 121714.60914999999  stock 1 number: 4456  stock 2 number: 1269  open cash48406.032749999984
# ..........
# 2003-10-06 00:00:00
# Total portfolio value: 123427.75914999998  stock 1 number: 4456  stock 2 number: 1269  open cash48353.142749999985
# ..........
# 2003-10-07 00:00:00
# Total portfolio value: 124605.40914999996  stock 1 number: 4456  stock 2 number: 1269  open cash48298.99274999998
# ..........
# 2003-10-08 00:00:00
# Total portfolio value: 125506.22114999997  stock 1 number: 4456  stock 2 number: 1269  open cash48244.08274999998
# ..........
# 2003-10-09 00:00:00
# Total portfolio value: 128300.73314999999  stock 1 number: 4456  stock 2 number: 1269  open cash48188.38274999998
# ..........
# 2003-10-10 00:00:00
# Total portfolio value: 128564.84994999997  stock 1 number: 4456  stock 2 number: 1269  open cash48130.52274999998
# ..........
# 2003-10-13 00:00:00
# Total portfolio value: 129006.52274999997  stock 1 number: 4456  stock 2 number: 1269  open cash48072.462749999984
# ..........
# 2003-10-14 00:00:00
# Total portfolio value: 131047.45834999997  stock 1 number: 4456  stock 2 number: 1269  open cash48014.16274999998
# ..........
# 2003-10-15 00:00:00
# Total portfolio value: 129322.98794999998  stock 1 number: 4456  stock 2 number: 1269  open cash47954.25274999998
# ..........
# 2003-10-16 00:00:00
# Total portfolio value: 130552.92194999997  stock 1 number: 4456  stock 2 number: 1269  open cash47895.71274999998
# ..........
# 2003-10-17 00:00:00
# Total portfolio value: 130075.69594999998  stock 1 number: 4456  stock 2 number: 1269  open cash47835.80274999997
# ..........
# 2003-10-20 00:00:00
# Total portfolio value: 130021.44914999997  stock 1 number: 4456  stock 2 number: 1269  open cash47776.11274999997
# ..........
# 2003-10-21 00:00:00
# Total portfolio value: 129646.15914999998  stock 1 number: 4456  stock 2 number: 1269  open cash47716.522749999975
# ..........
# 2003-10-22 00:00:00
# Total portfolio value: 122714.52594999998  stock 1 number: 4456  stock 2 number: 1269  open cash47657.172749999976
# ..........
# 2003-10-23 00:00:00
# Total portfolio value: 123093.11794999999  stock 1 number: 4456  stock 2 number: 1269  open cash47603.14274999998
# ..........
# 2003-10-24 00:00:00
# Total portfolio value: 123171.62714999999  stock 1 number: 4456  stock 2 number: 1269  open cash47548.82274999998
# ..........
# 2003-10-27 00:00:00
# Total portfolio value: 123612.02714999998  stock 1 number: 4456  stock 2 number: 1269  open cash47494.312749999975
# ..........
# 2003-10-28 00:00:00
# Total portfolio value: 126197.10994999997  stock 1 number: 4456  stock 2 number: 1269  open cash47439.412749999974
# ..........
# 2003-10-29 00:00:00
# Total portfolio value: 125995.44274999996  stock 1 number: 4456  stock 2 number: 1269  open cash47382.68274999997
# ..........
# 2003-10-30 00:00:00
# Total portfolio value: 124759.40954999997  stock 1 number: 4456  stock 2 number: 1269  open cash47326.06274999997
# ..........
# 2003-10-31 00:00:00
# Total portfolio value: 122876.18114999996  stock 1 number: 4456  stock 2 number: 1269  open cash47270.23274999997
# ..........
# 2003-11-03 00:00:00
# Total portfolio value: 125821.31794999997  stock 1 number: 4456  stock 2 number: 1269  open cash47215.802749999966
# ..........
# 2003-11-04 00:00:00
# Total portfolio value: 125854.91954999996  stock 1 number: 4456  stock 2 number: 1269  open cash47159.06274999997
# ..........
# 2003-11-05 00:00:00
# Total portfolio value: 125678.30834999996  stock 1 number: 4456  stock 2 number: 1269  open cash47102.20274999997
# ..........
# 2003-11-06 00:00:00
# Total portfolio value: 123423.98954999997  stock 1 number: 4456  stock 2 number: 1269  open cash47045.46274999997
# ..........
# 2003-11-07 00:00:00
# Total portfolio value: 122329.17634999997  stock 1 number: 4456  stock 2 number: 1269  open cash46990.47274999997
# ..........
# 2003-11-10 00:00:00
# Total portfolio value: 119148.32274999996  stock 1 number: 4456  stock 2 number: 1269  open cash46936.162749999974
# ..........
# 2003-11-11 00:00:00
# Total portfolio value: 119311.10474999997  stock 1 number: 4456  stock 2 number: 1269  open cash46884.18274999997
# ..........
# 2003-11-12 00:00:00
# Total portfolio value: 121892.32914999998  stock 1 number: 4456  stock 2 number: 1269  open cash46831.95274999997
# ..........
# 2003-11-13 00:00:00
# Total portfolio value: 122715.16514999996  stock 1 number: 4456  stock 2 number: 1269  open cash46777.82274999997
# ..........
# 2003-11-14 00:00:00
# Total portfolio value: 119405.06234999996  stock 1 number: 4456  stock 2 number: 1269  open cash46723.02274999997
# ..........
# 2003-11-17 00:00:00
# Total portfolio value: 116603.70714999997  stock 1 number: 4456  stock 2 number: 1269  open cash46670.57274999997
# ..........
# 2003-11-18 00:00:00
# Total portfolio value: 113992.93274999998  stock 1 number: 4456  stock 2 number: 1269  open cash46620.21274999997
# ..........
# 2003-11-19 00:00:00
# Total portfolio value: 115251.50274999996  stock 1 number: 4456  stock 2 number: 1269  open cash46571.71274999997
# ..........
# 2003-11-20 00:00:00
# Total portfolio value: 114327.91274999996  stock 1 number: 4456  stock 2 number: 1269  open cash46522.18274999997
# ..........
# 2003-11-21 00:00:00
# Total portfolio value: 113907.46874999997  stock 1 number: 4456  stock 2 number: 1269  open cash46473.33274999997
# ..........
# 2003-11-24 00:00:00
# Total portfolio value: 117594.60994999997  stock 1 number: 4456  stock 2 number: 1269  open cash46424.75274999997
# ..........
# 2003-11-25 00:00:00
# Total portfolio value: 118858.04234999996  stock 1 number: 4456  stock 2 number: 1269  open cash46373.42274999997
# ..........
# 2003-11-26 00:00:00
# Total portfolio value: 119439.85914999997  stock 1 number: 4456  stock 2 number: 1269  open cash46320.95274999997
# ..........
# 2003-11-28 00:00:00
# Total portfolio value: 120724.28914999997  stock 1 number: 4456  stock 2 number: 1269  open cash46267.99274999997
# ..........
# 2003-12-01 00:00:00
# Total portfolio value: 121761.38634999996  stock 1 number: 4456  stock 2 number: 1269  open cash46214.02274999997
# ..........
# 2003-12-02 00:00:00
# Total portfolio value: 120743.59474999996  stock 1 number: 4456  stock 2 number: 1269  open cash46159.372749999966
# ..........
# 2003-12-03 00:00:00
# Total portfolio value: 117474.31034999996  stock 1 number: 4456  stock 2 number: 1269  open cash46105.442749999966
# ..........
# 2003-12-04 00:00:00
# Total portfolio value: 117820.21994999996  stock 1 number: 4456  stock 2 number: 1269  open cash46053.93274999996
# ..........
# 2003-12-05 00:00:00
# Total portfolio value: 117383.20634999996  stock 1 number: 4456  stock 2 number: 1269  open cash46002.13274999996
# ..........
# 2003-12-08 00:00:00
# Total portfolio value: 116691.62434999995  stock 1 number: 4456  stock 2 number: 1269  open cash45950.57274999996
# ..........
# 2003-12-09 00:00:00
# Total portfolio value: 114344.48114999998  stock 1 number: 4456  stock 2 number: 1269  open cash45899.56274999996
# ..........
# 2003-12-10 00:00:00
# Total portfolio value: 114100.10274999996  stock 1 number: 4456  stock 2 number: 1269  open cash45850.222749999964
# ..........
# 2003-12-11 00:00:00
# Total portfolio value: 116320.58994999997  stock 1 number: 4456  stock 2 number: 1269  open cash45801.02274999997
# ..........
# 2003-12-12 00:00:00
# Total portfolio value: 116419.10634999996  stock 1 number: 4456  stock 2 number: 1269  open cash45750.222749999964
# ..........
# 2003-12-15 00:00:00
# Total portfolio value: 115427.56594999996  stock 1 number: 4456  stock 2 number: 1269  open cash45699.23274999997
# ..........
# 2003-12-16 00:00:00
# Total portfolio value: 114204.98754999996  stock 1 number: 4456  stock 2 number: 1269  open cash45648.82274999996
# ..........
# 2003-12-17 00:00:00
# Total portfolio value: 111650.83074999996  stock 1 number: 4456  stock 2 number: 1269  open cash45599.32274999996
# ..........
# 2003-12-18 00:00:00
# Total portfolio value: 113133.87754999996  stock 1 number: 4456  stock 2 number: 1269  open cash45551.74274999996
# ..........
# 2003-12-19 00:00:00
# Total portfolio value: 113609.35114999997  stock 1 number: 4456  stock 2 number: 1269  open cash45502.99274999996
# ..........
# 2003-12-22 00:00:00
# Total portfolio value: 114430.85794999998  stock 1 number: 4456  stock 2 number: 1269  open cash45453.75274999996
# ..........
# 2003-12-23 00:00:00
# Total portfolio value: 117649.85394999996  stock 1 number: 4456  stock 2 number: 1269  open cash45403.862749999964
# ..........
# 2003-12-24 00:00:00
# Total portfolio value: 118840.68274999996  stock 1 number: 4456  stock 2 number: 1269  open cash45351.38274999996
# ..........
# 2003-12-26 00:00:00
# Total portfolio value: 119081.09194999994  stock 1 number: 4456  stock 2 number: 1269  open cash45298.06274999996
# ..........
# 2003-12-29 00:00:00
# Total portfolio value: 119130.10994999995  stock 1 number: 4456  stock 2 number: 1269  open cash45244.59274999996
# ..........
# 2003-12-30 00:00:00
# Total portfolio value: 118304.13834999996  stock 1 number: 4456  stock 2 number: 1269  open cash45191.12274999996
# ..........
# 2003-12-31 00:00:00
# Total portfolio value: 118012.89114999995  stock 1 number: 4456  stock 2 number: 1269  open cash45138.29274999996
# ..........
# 2004-01-02 00:00:00
# Total portfolio value: 117018.51834999994  stock 1 number: 4456  stock 2 number: 1269  open cash45085.672749999954
# ..........
# 2004-01-05 00:00:00
# Total portfolio value: 118961.81394999995  stock 1 number: 4456  stock 2 number: 1269  open cash45033.77274999995
# ..........
# 2004-01-06 00:00:00
# Total portfolio value: 118574.57434999997  stock 1 number: 4456  stock 2 number: 1269  open cash44980.502749999956
# ..........
# 2004-01-07 00:00:00
# Total portfolio value: 117232.39434999994  stock 1 number: 4456  stock 2 number: 1269  open cash44927.47274999996
# ..........
# 2004-01-08 00:00:00
# Total portfolio value: 115294.52634999997  stock 1 number: 4456  stock 2 number: 1269  open cash44875.572749999956
# ..........
# 2004-01-09 00:00:00
# Total portfolio value: 116855.83954999996  stock 1 number: 4456  stock 2 number: 1269  open cash44825.33274999996
# ..........
# 2004-01-12 00:00:00
# Total portfolio value: 118740.85834999997  stock 1 number: 4456  stock 2 number: 1269  open cash44773.74274999996
# ..........
# 2004-01-13 00:00:00
# Total portfolio value: 121282.98354999996  stock 1 number: 4456  stock 2 number: 1269  open cash44720.792749999964
# ..........
# 2004-01-14 00:00:00
# Total portfolio value: 122380.20914999995  stock 1 number: 4456  stock 2 number: 1269  open cash44665.88274999996
# ..........
# 2004-01-15 00:00:00
# Total portfolio value: 122424.74994999995  stock 1 number: 4456  stock 2 number: 1269  open cash44610.08274999996
# ..........
# 2004-01-16 00:00:00
# Total portfolio value: 121744.72594999996  stock 1 number: 4456  stock 2 number: 1269  open cash44553.90274999996
# ..........
# 2004-01-20 00:00:00
# Total portfolio value: 122823.31754999995  stock 1 number: 4456  stock 2 number: 1269  open cash44498.182749999956
# ..........
# 2004-01-21 00:00:00
# Total portfolio value: 122208.98714999997  stock 1 number: 4456  stock 2 number: 1269  open cash44441.572749999956
# ..........
# 2004-01-22 00:00:00
# Total portfolio value: 123275.20394999997  stock 1 number: 4456  stock 2 number: 1269  open cash44385.37274999996
# ..........
# 2004-01-23 00:00:00
# Total portfolio value: 123238.81154999995  stock 1 number: 4456  stock 2 number: 1269  open cash44328.19274999996
# ..........
# 2004-01-26 00:00:00
# Total portfolio value: 123209.40554999997  stock 1 number: 4456  stock 2 number: 1269  open cash44271.08274999996
# ..........
# 2004-01-27 00:00:00
# Total portfolio value: 121533.18954999995  stock 1 number: 4456  stock 2 number: 1269  open cash44214.05274999996
# ..........
# 2004-01-28 00:00:00
# Total portfolio value: 116521.55034999998  stock 1 number: 4456  stock 2 number: 1269  open cash44158.31274999996
# ..........
# 2004-01-29 00:00:00
# Total portfolio value: 113037.09034999995  stock 1 number: 4456  stock 2 number: 1269  open cash44106.35274999996
# ..........
# 2004-01-30 00:00:00
# Total portfolio value: 114452.76154999997  stock 1 number: 4456  stock 2 number: 1269  open cash44057.13274999996
# ..........
# 2004-02-02 00:00:00
# Total portfolio value: 111630.76914999998  stock 1 number: 4456  stock 2 number: 1269  open cash44006.73274999996
# ..........
# 2004-02-03 00:00:00
# Total portfolio value: 107340.24194999997  stock 1 number: 4456  stock 2 number: 1269  open cash43958.46274999996
# ..........
# 2004-02-04 00:00:00
# Total portfolio value: 107727.77034999996  stock 1 number: 4456  stock 2 number: 1269  open cash43913.52274999996
# ..........
# 2004-02-05 00:00:00
# Total portfolio value: 108689.03514999995  stock 1 number: 4456  stock 2 number: 1269  open cash43868.13274999996
# ..........
# 2004-02-06 00:00:00
# Total portfolio value: 109122.38594999997  stock 1 number: 4456  stock 2 number: 1269  open cash43822.09274999996
# ..........
# 2004-02-09 00:00:00
# Total portfolio value: 108442.64034999996  stock 1 number: 4456  stock 2 number: 1269  open cash43775.74274999996
# ..........
# 2004-02-10 00:00:00
# Total portfolio value: 108141.48794999997  stock 1 number: 4456  stock 2 number: 1269  open cash43729.88274999996
# ..........
# 2004-02-11 00:00:00
# Total portfolio value: 110295.89674999997  stock 1 number: 4456  stock 2 number: 1269  open cash43684.292749999964
# ..........
# 2004-02-12 00:00:00
# Total portfolio value: 110129.85834999997  stock 1 number: 4456  stock 2 number: 1269  open cash43637.152749999965
# ..........
# 2004-02-13 00:00:00
# Total portfolio value: 109009.10954999996  stock 1 number: 4456  stock 2 number: 1269  open cash43590.09274999997
# ..........
# 2004-02-17 00:00:00
# Total portfolio value: 107929.08514999997  stock 1 number: 4456  stock 2 number: 1269  open cash43543.71274999997
# ..........
# 2004-02-18 00:00:00
# Total portfolio value: 107074.97914999997  stock 1 number: 4456  stock 2 number: 1269  open cash43498.18274999997
# ..........
# 2004-02-19 00:00:00
# Total portfolio value: 106521.44514999997  stock 1 number: 4456  stock 2 number: 1269  open cash43453.31274999997
# ..........
# 2004-02-20 00:00:00
# Total portfolio value: 107119.29674999998  stock 1 number: 4456  stock 2 number: 1269  open cash43408.66274999997
# ..........
# 2004-02-23 00:00:00
# Total portfolio value: 105496.07234999997  stock 1 number: 4456  stock 2 number: 1269  open cash43363.49274999997
# ..........
# 2004-02-24 00:00:00
# Total portfolio value: 103402.81234999996  stock 1 number: 4456  stock 2 number: 1269  open cash43319.52274999997
# ..........
# 2004-02-25 00:00:00
# Total portfolio value: 104272.93154999996  stock 1 number: 4456  stock 2 number: 1269  open cash43277.20274999997
# ..........
# 2004-02-26 00:00:00
# Total portfolio value: 105199.15834999995  stock 1 number: 4456  stock 2 number: 1269  open cash43234.262749999965
# ..........
# 2004-02-27 00:00:00
# Total portfolio value: 104594.66674999996  stock 1 number: 4456  stock 2 number: 1269  open cash43190.612749999964
# ..........
# 2004-03-01 00:00:00
# Total portfolio value: 104530.75194999996  stock 1 number: 4456  stock 2 number: 1269  open cash43147.60274999996
# ..........
# 2004-03-02 00:00:00
# Total portfolio value: 103206.26674999995  stock 1 number: 4456  stock 2 number: 1269  open cash43104.63274999996
# ..........
# 2004-03-03 00:00:00
# Total portfolio value: 104669.71674999996  stock 1 number: 4456  stock 2 number: 1269  open cash43062.62274999996
# ..........
# 2004-03-04 00:00:00
# Total portfolio value: 106528.53314999997  stock 1 number: 4456  stock 2 number: 1269  open cash43019.45274999996
# ..........
# 2004-03-05 00:00:00
# Total portfolio value: 106555.72714999996  stock 1 number: 4456  stock 2 number: 1269  open cash42975.06274999996
# ..........
# 2004-03-08 00:00:00
# Total portfolio value: 105550.82154999996  stock 1 number: 4456  stock 2 number: 1269  open cash42930.972749999964
# ..........
# 2004-03-09 00:00:00
# Total portfolio value: 104819.85074999995  stock 1 number: 4456  stock 2 number: 1269  open cash42887.472749999964
# ..........
# 2004-03-10 00:00:00
# Total portfolio value: 103468.19034999996  stock 1 number: 4456  stock 2 number: 1269  open cash42844.762749999965
# ..........
# 2004-03-11 00:00:00
# Total portfolio value: 102932.06074999996  stock 1 number: 4456  stock 2 number: 1269  open cash42803.21274999996
# ..........
# 2004-03-12 00:00:00
# Total portfolio value: 104482.68714999995  stock 1 number: 4456  stock 2 number: 1269  open cash42761.93274999996
# ..........
# 2004-03-15 00:00:00
# Total portfolio value: 102394.02074999997  stock 1 number: 4456  stock 2 number: 1269  open cash42719.49274999996
# ..........
# 2004-03-16 00:00:00
# Total portfolio value: 103508.93314999997  stock 1 number: 4456  stock 2 number: 1269  open cash42678.41274999996
# ..........
# 2004-03-17 00:00:00
# Total portfolio value: 104423.97714999996  stock 1 number: 4456  stock 2 number: 1269  open cash42636.28274999996
# ..........
# 2004-03-18 00:00:00
# Total portfolio value: 104499.72794999996  stock 1 number: 4456  stock 2 number: 1269  open cash42593.48274999996
# ..........
# 2004-03-19 00:00:00
# Total portfolio value: 104241.91754999995  stock 1 number: 4456  stock 2 number: 1269  open cash42550.47274999996
# ..........
# 2004-03-22 00:00:00
# Total portfolio value: 101724.56754999995  stock 1 number: 4456  stock 2 number: 1269  open cash42507.672749999954
# ..........
# 2004-03-23 00:00:00
# Total portfolio value: 100732.51114999995  stock 1 number: 4456  stock 2 number: 1269  open cash42466.822749999956
# ..........
# 2004-03-24 00:00:00
# Total portfolio value: 99992.81954999996  stock 1 number: 4456  stock 2 number: 1269  open cash42426.59274999995
# ..........
# 2004-03-25 00:00:00
# Total portfolio value: 103341.49434999996  stock 1 number: 4456  stock 2 number: 1269  open cash42386.962749999955
# ..........
# 2004-03-26 00:00:00
# Total portfolio value: 102977.83674999996  stock 1 number: 4456  stock 2 number: 1269  open cash42344.97274999996
# ..........
# 2004-03-29 00:00:00
# Total portfolio value: 104533.04074999996  stock 1 number: 4456  stock 2 number: 1269  open cash42303.27274999996
# ..........
# 2004-03-30 00:00:00
# Total portfolio value: 105810.04074999996  stock 1 number: 4456  stock 2 number: 1269  open cash42260.51274999996
# ..........
# 2004-03-31 00:00:00
# Total portfolio value: 104854.59674999995  stock 1 number: 4456  stock 2 number: 1269  open cash42216.712749999955
# ..........
# 2004-04-01 00:00:00
# Total portfolio value: 106681.88074999995  stock 1 number: 4456  stock 2 number: 1269  open cash42173.432749999956
# ..........
# 2004-04-02 00:00:00
# Total portfolio value: 108464.36434999996  stock 1 number: 4456  stock 2 number: 1269  open cash42128.69274999996
# ..........
# 2004-04-05 00:00:00
# Total portfolio value: 109754.90754999996  stock 1 number: 4456  stock 2 number: 1269  open cash42082.60274999996
# ..........
# 2004-04-06 00:00:00
# Total portfolio value: 108905.92114999995  stock 1 number: 4456  stock 2 number: 1269  open cash42035.64274999996
# ..........
# 2004-04-07 00:00:00
# Total portfolio value: 107961.49514999997  stock 1 number: 4456  stock 2 number: 1269  open cash41989.20274999996
# ..........
# 2004-04-08 00:00:00
# Total portfolio value: 110840.40874999996  stock 1 number: 4456  stock 2 number: 1269  open cash41943.35274999996
# ..........
# 2004-04-12 00:00:00
# Total portfolio value: 110755.45834999997  stock 1 number: 4456  stock 2 number: 1269  open cash41895.25274999996
# ..........
# 2004-04-13 00:00:00
# Total portfolio value: 108637.67434999996  stock 1 number: 4456  stock 2 number: 1269  open cash41847.292749999964
# ..........
# 2004-04-14 00:00:00
# Total portfolio value: 108778.26754999996  stock 1 number: 4456  stock 2 number: 1269  open cash41800.71274999996
# ..........
# 2004-04-15 00:00:00
# Total portfolio value: 109744.57994999996  stock 1 number: 4456  stock 2 number: 1269  open cash41753.92274999996
# ..........
# 2004-04-16 00:00:00
# Total portfolio value: 107771.13194999997  stock 1 number: 4456  stock 2 number: 1269  open cash41706.93274999996
# ..........
# 2004-04-19 00:00:00
# Total portfolio value: 109534.78194999996  stock 1 number: 4456  stock 2 number: 1269  open cash41661.43274999996
# ..........
# 2004-04-20 00:00:00
# Total portfolio value: 106887.42434999996  stock 1 number: 4456  stock 2 number: 1269  open cash41614.32274999996
# ..........
# 2004-04-21 00:00:00
# Total portfolio value: 107502.10434999997  stock 1 number: 4456  stock 2 number: 1269  open cash41569.122749999966
# ..........
# 2004-04-22 00:00:00
# Total portfolio value: 111453.07554999997  stock 1 number: 4456  stock 2 number: 1269  open cash41523.402749999965
# ..........
# 2004-04-23 00:00:00
# Total portfolio value: 108118.82314999997  stock 1 number: 4456  stock 2 number: 1269  open cash41474.542749999964
# ..........
# 2004-04-26 00:00:00
# Total portfolio value: 109126.79234999997  stock 1 number: 4456  stock 2 number: 1269  open cash41428.25274999996
# ..........
# 2004-04-27 00:00:00
# Total portfolio value: 109979.15714999996  stock 1 number: 4456  stock 2 number: 1269  open cash41381.00274999996
# ..........
# 2004-04-28 00:00:00
# Total portfolio value: 108481.94074999995  stock 1 number: 4456  stock 2 number: 1269  open cash41333.00274999996
# ..........
# 2004-04-29 00:00:00
# Total portfolio value: 107536.94434999998  stock 1 number: 4456  stock 2 number: 1269  open cash41286.03274999996
# ..........
# 2004-04-30 00:00:00
# Total portfolio value: 103923.76194999996  stock 1 number: 4456  stock 2 number: 1269  open cash41239.84274999996
# ..........
# 2004-05-03 00:00:00
# Total portfolio value: 104994.94394999996  stock 1 number: 4456  stock 2 number: 1269  open cash41196.24274999996
# ..........
# 2004-05-04 00:00:00
# Total portfolio value: 104382.38994999995  stock 1 number: 4456  stock 2 number: 1269  open cash41151.83274999996
# ..........
# 2004-05-05 00:00:00
# Total portfolio value: 104874.86754999995  stock 1 number: 4456  stock 2 number: 1269  open cash41107.88274999996
# ..........
# 2004-05-06 00:00:00
# Total portfolio value: 103392.39474999996  stock 1 number: 4456  stock 2 number: 1269  open cash41063.62274999996
# ..........
# 2004-05-07 00:00:00
# Total portfolio value: 101804.21314999997  stock 1 number: 4456  stock 2 number: 1269  open cash41020.48274999996
# ..........
# 2004-05-10 00:00:00
# Total portfolio value: 100836.52514999994  stock 1 number: 4456  stock 2 number: 1269  open cash40978.58274999996
# ..........
# 2004-05-11 00:00:00
# Total portfolio value: 102868.15074999996  stock 1 number: 4456  stock 2 number: 1269  open cash40937.322749999956
# ..........
# 2004-05-12 00:00:00
# Total portfolio value: 103275.64514999997  stock 1 number: 4456  stock 2 number: 1269  open cash40894.62274999996
# ..........
# 2004-05-13 00:00:00
# Total portfolio value: 103953.70794999995  stock 1 number: 4456  stock 2 number: 1269  open cash40851.60274999996
# ..........
# 2004-05-14 00:00:00
# Total portfolio value: 103159.79954999997  stock 1 number: 4456  stock 2 number: 1269  open cash40807.99274999996
# ..........
# 2004-05-17 00:00:00
# Total portfolio value: 101765.50754999995  stock 1 number: 4456  stock 2 number: 1269  open cash40764.94274999996
# ..........
# 2004-05-18 00:00:00
# Total portfolio value: 101729.52954999996  stock 1 number: 4456  stock 2 number: 1269  open cash40722.86274999996
# ..........
# 2004-05-19 00:00:00
# Total portfolio value: 101135.28354999996  stock 1 number: 4456  stock 2 number: 1269  open cash40680.87274999996
# ..........
# 2004-05-20 00:00:00
# Total portfolio value: 100267.01874999996  stock 1 number: 4456  stock 2 number: 1269  open cash40639.182749999956
# ..........
# 2004-05-21 00:00:00
# Total portfolio value: 100576.32074999996  stock 1 number: 4456  stock 2 number: 1269  open cash40598.20274999995
# ..........
# 2004-05-24 00:00:00
# Total portfolio value: 101186.17634999997  stock 1 number: 4456  stock 2 number: 1269  open cash40557.032749999955
# ..........
# 2004-05-25 00:00:00
# Total portfolio value: 103977.32034999997  stock 1 number: 4456  stock 2 number: 1269  open cash40515.40274999996
# ..........
# 2004-05-26 00:00:00
# Total portfolio value: 105320.93994999996  stock 1 number: 4456  stock 2 number: 1269  open cash40471.782749999955
# ..........
# 2004-05-27 00:00:00
# Total portfolio value: 108897.72474999995  stock 1 number: 4456  stock 2 number: 1269  open cash40427.09274999995
# ..........
# 2004-05-28 00:00:00
# Total portfolio value: 109931.17674999996  stock 1 number: 4456  stock 2 number: 1269  open cash40379.47274999995
# ..........
# 2004-06-01 00:00:00
# Total portfolio value: 112078.04674999995  stock 1 number: 4456  stock 2 number: 1269  open cash40330.97274999995
# ..........
# 2004-06-02 00:00:00
# Total portfolio value: 112426.06794999995  stock 1 number: 4456  stock 2 number: 1269  open cash40280.74274999995
# ..........
# 2004-06-03 00:00:00
# Total portfolio value: 111020.89194999993  stock 1 number: 4456  stock 2 number: 1269  open cash40230.39274999995
# ..........
# 2004-06-04 00:00:00
# Total portfolio value: 113048.05954999995  stock 1 number: 4456  stock 2 number: 1269  open cash40180.99274999995
# ..........
# 2004-06-07 00:00:00
# Total portfolio value: 114315.08514999996  stock 1 number: 4456  stock 2 number: 1269  open cash40130.04274999995
# ..........
# 2004-06-08 00:00:00
# Total portfolio value: 114651.71554999994  stock 1 number: 4456  stock 2 number: 1269  open cash40078.28274999995
# ..........
# 2004-06-09 00:00:00
# Total portfolio value: 112397.02434999996  stock 1 number: 4456  stock 2 number: 1269  open cash40026.342749999945
# ..........
# 2004-06-10 00:00:00
# Total portfolio value: 112120.26194999994  stock 1 number: 4456  stock 2 number: 1269  open cash39976.10274999995
# ..........
# 2004-06-14 00:00:00
# Total portfolio value: 111018.25434999994  stock 1 number: 4456  stock 2 number: 1269  open cash39926.162749999945
# ..........
# 2004-06-15 00:00:00
# Total portfolio value: 112225.66194999994  stock 1 number: 4456  stock 2 number: 1269  open cash39876.912749999945
# ..........
# 2004-06-16 00:00:00
# Total portfolio value: 113341.69114999994  stock 1 number: 4456  stock 2 number: 1269  open cash39826.802749999944
# ..........
# 2004-06-17 00:00:00
# Total portfolio value: 112299.09234999993  stock 1 number: 4456  stock 2 number: 1269  open cash39776.232749999945
# ..........
# 2004-06-18 00:00:00
# Total portfolio value: 112055.87234999995  stock 1 number: 4456  stock 2 number: 1269  open cash39726.46274999995
# ..........
# 2004-06-21 00:00:00
# Total portfolio value: 112056.68474999996  stock 1 number: 4456  stock 2 number: 1269  open cash39676.86274999995
# ..........
# 2004-06-22 00:00:00
# Total portfolio value: 111223.62074999996  stock 1 number: 4456  stock 2 number: 1269  open cash39627.09274999995
# ..........
# 2004-06-23 00:00:00
# Total portfolio value: 113670.24834999995  stock 1 number: 4456  stock 2 number: 1269  open cash39578.09274999995
# ..........
# 2004-06-24 00:00:00
# Total portfolio value: 113739.32594999995  stock 1 number: 4456  stock 2 number: 1269  open cash39527.282749999955
# ..........
# 2004-06-25 00:00:00
# Total portfolio value: 114824.72834999996  stock 1 number: 4456  stock 2 number: 1269  open cash39476.26274999996
# ..........
# 2004-06-28 00:00:00
# Total portfolio value: 116449.30874999997  stock 1 number: 4456  stock 2 number: 1269  open cash39424.462749999955
# ..........
# 2004-06-29 00:00:00
# Total portfolio value: 116801.99874999997  stock 1 number: 4456  stock 2 number: 1269  open cash39371.072749999956
# ..........
# 2004-06-30 00:00:00
# Total portfolio value: 117635.48434999994  stock 1 number: 4456  stock 2 number: 1269  open cash39317.36274999996
# ..........
# 2004-07-01 00:00:00
# Total portfolio value: 115177.50194999995  stock 1 number: 4456  stock 2 number: 1269  open cash39262.962749999955
# ..........
# 2004-07-02 00:00:00
# Total portfolio value: 114814.99834999995  stock 1 number: 4456  stock 2 number: 1269  open cash39210.40274999996
# ..........
# 2004-07-06 00:00:00
# Total portfolio value: 113008.70874999996  stock 1 number: 4456  stock 2 number: 1269  open cash39157.81274999996
# ..........
# 2004-07-07 00:00:00
# Total portfolio value: 112499.17674999996  stock 1 number: 4456  stock 2 number: 1269  open cash39106.57274999996
# ..........
# 2004-07-08 00:00:00
# Total portfolio value: 110471.59834999996  stock 1 number: 4456  stock 2 number: 1269  open cash39055.57274999996
# ..........
# 2004-07-09 00:00:00
# Total portfolio value: 108895.71434999997  stock 1 number: 4456  stock 2 number: 1269  open cash39006.07274999996
# ..........
# 2004-07-12 00:00:00
# Total portfolio value: 109516.20754999996  stock 1 number: 4456  stock 2 number: 1269  open cash38957.75274999996
# ..........
# 2004-07-13 00:00:00
# Total portfolio value: 110187.38754999996  stock 1 number: 4456  stock 2 number: 1269  open cash38908.70274999996
# ..........
# 2004-07-14 00:00:00
# Total portfolio value: 110114.71234999996  stock 1 number: 4456  stock 2 number: 1269  open cash38859.10274999996
# ..........
# 2004-07-15 00:00:00
# Total portfolio value: 109964.18954999997  stock 1 number: 4456  stock 2 number: 1269  open cash38809.60274999996
# ..........
# 2004-07-16 00:00:00
# Total portfolio value: 107718.21354999997  stock 1 number: 4456  stock 2 number: 1269  open cash38760.93274999996
# ..........
# 2004-07-19 00:00:00
# Total portfolio value: 106231.07994999996  stock 1 number: 4456  stock 2 number: 1269  open cash38713.832749999965
# ..........
# 2004-07-20 00:00:00
# Total portfolio value: 107485.50354999998  stock 1 number: 4456  stock 2 number: 1269  open cash38667.81274999997
# ..........
# 2004-07-21 00:00:00
# Total portfolio value: 104442.88034999996  stock 1 number: 4456  stock 2 number: 1269  open cash38620.82274999997
# ..........
# 2004-07-22 00:00:00
# Total portfolio value: 105760.63874999997  stock 1 number: 4456  stock 2 number: 1269  open cash38576.06274999997
# ..........
# 2004-07-23 00:00:00
# Total portfolio value: 98024.02194999997  stock 1 number: 4456  stock 2 number: 1269  open cash38530.24274999997
# ..........
# 2004-07-26 00:00:00
# Total portfolio value: 96621.21234999996  stock 1 number: 4456  stock 2 number: 1269  open cash38490.262749999965
# ..........
# 2004-07-27 00:00:00
# Total portfolio value: 97331.83754999997  stock 1 number: 4456  stock 2 number: 1269  open cash38451.48274999997
# ..........
# 2004-07-28 00:00:00
# Total portfolio value: 95806.85474999997  stock 1 number: 4456  stock 2 number: 1269  open cash38412.372749999966
# ..........
# 2004-07-29 00:00:00
# Total portfolio value: 96645.01714999997  stock 1 number: 4456  stock 2 number: 1269  open cash38374.402749999965
# ..........
# 2004-07-30 00:00:00
# Total portfolio value: 96952.78754999996  stock 1 number: 4456  stock 2 number: 1269  open cash38335.82274999996
# ..........
# 2004-08-02 00:00:00
# Total portfolio value: 95910.08034999996  stock 1 number: 4456  stock 2 number: 1269  open cash38296.902749999965
# ..........
# 2004-08-03 00:00:00
# Total portfolio value: 94911.06074999996  stock 1 number: 4456  stock 2 number: 1269  open cash38258.60274999996
# ..........
# 2004-08-04 00:00:00
# Total portfolio value: 94394.23274999997  stock 1 number: 4456  stock 2 number: 1269  open cash38220.99274999996
# ..........
# 2004-08-05 00:00:00
# Total portfolio value: 92332.19634999995  stock 1 number: 4456  stock 2 number: 1269  open cash38183.87274999996
# ..........
# 2004-08-06 00:00:00
# Total portfolio value: 91682.66474999997  stock 1 number: 4456  stock 2 number: 1269  open cash38148.26274999996
# ..........
# 2004-08-09 00:00:00
# Total portfolio value: 91578.93834999995  stock 1 number: 4456  stock 2 number: 1269  open cash38112.77274999996
# ..........
# 2004-08-10 00:00:00
# Total portfolio value: 94150.45194999996  stock 1 number: 4456  stock 2 number: 1269  open cash38077.45274999996
# ..........
# 2004-08-11 00:00:00
# Total portfolio value: 93286.39114999995  stock 1 number: 4456  stock 2 number: 1269  open cash38040.35274999996
# ..........
# 2004-08-12 00:00:00
# Total portfolio value: 92723.61394999997  stock 1 number: 4456  stock 2 number: 1269  open cash38003.792749999964
# ..........
# 2004-08-13 00:00:00
# Total portfolio value: 92616.62714999996  stock 1 number: 4456  stock 2 number: 1269  open cash37967.50274999996
# ..........
# 2004-08-16 00:00:00
# Total portfolio value: 94872.25314999997  stock 1 number: 4456  stock 2 number: 1269  open cash37931.372749999966
# ..........
# 2004-08-17 00:00:00
# Total portfolio value: 95218.14154999997  stock 1 number: 4456  stock 2 number: 1269  open cash37893.42274999997
# ..........
# 2004-08-18 00:00:00
# Total portfolio value: 96859.85274999996  stock 1 number: 4456  stock 2 number: 1269  open cash37855.192749999966
# ..........
# 2004-08-19 00:00:00
# Total portfolio value: 95601.80914999996  stock 1 number: 4456  stock 2 number: 1269  open cash37815.832749999965
# ..........
# 2004-08-20 00:00:00
# Total portfolio value: 96703.51594999997  stock 1 number: 4456  stock 2 number: 1269  open cash37777.20274999997
# ..........
# 2004-08-23 00:00:00
# Total portfolio value: 96667.62834999997  stock 1 number: 4456  stock 2 number: 1269  open cash37737.692749999966
# ..........
# 2004-08-24 00:00:00
# Total portfolio value: 96364.76714999997  stock 1 number: 4456  stock 2 number: 1269  open cash37698.24274999997
# ..........
# 2004-08-25 00:00:00
# Total portfolio value: 98226.56074999996  stock 1 number: 4456  stock 2 number: 1269  open cash37659.192749999966
# ..........
# 2004-08-26 00:00:00
# Total portfolio value: 98509.20354999996  stock 1 number: 4456  stock 2 number: 1269  open cash37618.89274999996
# ..........
# 2004-08-27 00:00:00
# Total portfolio value: 98015.44834999996  stock 1 number: 4456  stock 2 number: 1269  open cash37578.70274999996
# ..........
# 2004-08-30 00:00:00
# Total portfolio value: 95888.77034999996  stock 1 number: 4456  stock 2 number: 1269  open cash37538.80274999996
# ..........
# 2004-08-31 00:00:00
# Total portfolio value: 95743.90234999996  stock 1 number: 4456  stock 2 number: 1269  open cash37500.49274999996
# ..........
# 2004-09-01 00:00:00
# Total portfolio value: 96220.33434999996  stock 1 number: 4456  stock 2 number: 1269  open cash37462.35274999996
# ..........
# 2004-09-02 00:00:00
# Total portfolio value: 97317.91754999995  stock 1 number: 4456  stock 2 number: 1269  open cash37424.112749999964
# ..........
# 2004-09-03 00:00:00
# Total portfolio value: 96595.16394999996  stock 1 number: 4456  stock 2 number: 1269  open cash37384.93274999996
# ..........
# 2004-09-07 00:00:00
# Total portfolio value: 96419.17714999996  stock 1 number: 4456  stock 2 number: 1269  open cash37346.192749999966
# ..........
# 2004-09-08 00:00:00
# Total portfolio value: 95915.49514999996  stock 1 number: 4456  stock 2 number: 1269  open cash37307.68274999996
# ..........
# 2004-09-09 00:00:00
# Total portfolio value: 95766.91874999995  stock 1 number: 4456  stock 2 number: 1269  open cash37269.67274999996
# ..........
# 2004-09-10 00:00:00
# ...
# ..........
# 2004-12-03 00:00:00
# Total portfolio value: 103680.04874999996  stock 1 number: 4456  stock 2 number: 1269  open cash34921.682749999956
# ..........
# 2004-12-06 00:00:00
# Total portfolio value: 103763.07474999997  stock 1 number: 4456  stock 2 number: 1269  open cash34881.59274999996
# ..........
# 2004-12-07 00:00:00
# Total portfolio value: 101264.44274999996  stock 1 number: 4456  stock 2 number: 1269  open cash34842.10274999996
# ..........
# 2004-12-08 00:00:00
# Total portfolio value: 101994.84914999997  stock 1 number: 4456  stock 2 number: 1269  open cash34803.902749999965
# ..........
# 2004-12-09 00:00:00
# Total portfolio value: 103557.45074999996  stock 1 number: 4456  stock 2 number: 1269  open cash34765.18274999996
# ..........
# 2004-12-10 00:00:00
# Total portfolio value: 102870.69034999996  stock 1 number: 4456  stock 2 number: 1269  open cash34725.362749999964
# ..........
# 2004-12-13 00:00:00
# Total portfolio value: 103747.93634999995  stock 1 number: 4456  stock 2 number: 1269  open cash34686.31274999996
# ..........
# 2004-12-14 00:00:00
# Total portfolio value: 104597.16114999997  stock 1 number: 4456  stock 2 number: 1269  open cash34646.48274999996
# ..........
# 2004-12-15 00:00:00
# Total portfolio value: 105255.77554999996  stock 1 number: 4456  stock 2 number: 1269  open cash34606.04274999996
# ..........
# 2004-12-16 00:00:00
# Total portfolio value: 104391.10474999997  stock 1 number: 4456  stock 2 number: 1269  open cash34565.04274999996
# ..........
# 2004-12-17 00:00:00
# Total portfolio value: 103837.76194999996  stock 1 number: 4456  stock 2 number: 1269  open cash34524.992749999954
# ..........
# 2004-12-20 00:00:00
# Total portfolio value: 101807.82874999996  stock 1 number: 4456  stock 2 number: 1269  open cash34484.98274999995
# ..........
# 2004-12-21 00:00:00
# Total portfolio value: 102600.39154999996  stock 1 number: 4456  stock 2 number: 1269  open cash34446.032749999955
# ..........
# 2004-12-22 00:00:00
# Total portfolio value: 102749.14274999996  stock 1 number: 4456  stock 2 number: 1269  open cash34406.642749999955
# ..........
# 2004-12-23 00:00:00
# Total portfolio value: 102036.21914999996  stock 1 number: 4456  stock 2 number: 1269  open cash34367.12274999996
# ..........
# 2004-12-27 00:00:00
# Total portfolio value: 105964.39794999996  stock 1 number: 4456  stock 2 number: 1269  open cash34328.19274999996
# ..........
# 2004-12-28 00:00:00
# Total portfolio value: 109233.34474999996  stock 1 number: 4456  stock 2 number: 1269  open cash34285.94274999996
# ..........
# 2004-12-29 00:00:00
# Total portfolio value: 109503.79434999995  stock 1 number: 4456  stock 2 number: 1269  open cash34241.31274999996
# ..........
# 2004-12-30 00:00:00
# Total portfolio value: 109751.81234999996  stock 1 number: 4456  stock 2 number: 1269  open cash34196.49274999996
# ..........
# 2004-12-31 00:00:00
# Total portfolio value: 108730.29434999997  stock 1 number: 4456  stock 2 number: 1269  open cash34151.52274999996
# ..........
# 2005-01-03 00:00:00
# Total portfolio value: 108658.37914999996  stock 1 number: 4456  stock 2 number: 1269  open cash34107.23274999996
# ..........
# 2005-01-04 00:00:00
# Total portfolio value: 105781.23674999997  stock 1 number: 4456  stock 2 number: 1269  open cash34062.71274999996
# ..........
# 2005-01-05 00:00:00
# Total portfolio value: 105429.98274999997  stock 1 number: 4456  stock 2 number: 1269  open cash34020.57274999996
# ..........
# 2005-01-06 00:00:00
# Total portfolio value: 104485.22714999996  stock 1 number: 4456  stock 2 number: 1269  open cash33978.802749999966
# ..........
# 2005-01-07 00:00:00
# Total portfolio value: 107397.95434999996  stock 1 number: 4456  stock 2 number: 1269  open cash33937.75274999996
# ..........
# 2005-01-10 00:00:00
# Total portfolio value: 106666.75194999998  stock 1 number: 4456  stock 2 number: 1269  open cash33895.43274999996
# ..........
# 2005-01-11 00:00:00
# Total portfolio value: 105114.96554999998  stock 1 number: 4456  stock 2 number: 1269  open cash33853.59274999997
# ..........
# 2005-01-12 00:00:00
# Total portfolio value: 106167.97674999996  stock 1 number: 4456  stock 2 number: 1269  open cash33811.95274999997
# ..........
# 2005-01-13 00:00:00
# Total portfolio value: 107743.80794999997  stock 1 number: 4456  stock 2 number: 1269  open cash33769.652749999965
# ..........
# 2005-01-14 00:00:00
# Total portfolio value: 110291.16834999996  stock 1 number: 4456  stock 2 number: 1269  open cash33727.052749999966
# ..........
# 2005-01-18 00:00:00
# Total portfolio value: 110415.24914999996  stock 1 number: 4456  stock 2 number: 1269  open cash33682.50274999996
# ..........
# 2005-01-19 00:00:00
# Total portfolio value: 109361.53474999996  stock 1 number: 4456  stock 2 number: 1269  open cash33637.92274999996
# ..........
# 2005-01-20 00:00:00
# Total portfolio value: 107452.93794999996  stock 1 number: 4456  stock 2 number: 1269  open cash33593.96274999996
# ..........
# 2005-01-21 00:00:00
# Total portfolio value: 105893.12514999995  stock 1 number: 4456  stock 2 number: 1269  open cash33551.60274999996
# ..........
# 2005-01-24 00:00:00
# Total portfolio value: 104942.35314999995  stock 1 number: 4456  stock 2 number: 1269  open cash33510.44274999996
# ..........
# 2005-01-25 00:00:00
# Total portfolio value: 105977.55954999995  stock 1 number: 4456  stock 2 number: 1269  open cash33470.06274999996
# ..........
# 2005-01-26 00:00:00
# Total portfolio value: 106502.14754999997  stock 1 number: 4456  stock 2 number: 1269  open cash33429.12274999996
# ..........
# 2005-01-27 00:00:00
# Total portfolio value: 107804.91994999995  stock 1 number: 4456  stock 2 number: 1269  open cash33387.78274999996
# ..........
# 2005-01-28 00:00:00
# Total portfolio value: 108030.72474999996  stock 1 number: 4456  stock 2 number: 1269  open cash33345.472749999964
# ..........
# 2005-01-31 00:00:00
# Total portfolio value: 110090.33114999995  stock 1 number: 4456  stock 2 number: 1269  open cash33303.25274999996
# ..........
# 2005-02-01 00:00:00
# Total portfolio value: 109292.08394999997  stock 1 number: 4456  stock 2 number: 1269  open cash33260.03274999996
# ..........
# 2005-02-02 00:00:00
# Total portfolio value: 109079.96074999995  stock 1 number: 4456  stock 2 number: 1269  open cash33217.55274999996
# ..........
# 2005-02-03 00:00:00
# Total portfolio value: 100746.22514999995  stock 1 number: 4456  stock 2 number: 1269  open cash33175.67274999996
# ..........
# 2005-02-04 00:00:00
# Total portfolio value: 100964.71874999997  stock 1 number: 4456  stock 2 number: 1269  open cash33139.92274999996
# ..........
# 2005-02-07 00:00:00
# Total portfolio value: 100917.21914999996  stock 1 number: 4456  stock 2 number: 1269  open cash33104.20274999996
# ..........
# 2005-02-08 00:00:00
# Total portfolio value: 102216.62954999995  stock 1 number: 4456  stock 2 number: 1269  open cash33068.51274999996
# ..........
# 2005-02-09 00:00:00
# Total portfolio value: 101043.32914999995  stock 1 number: 4456  stock 2 number: 1269  open cash33032.212749999955
# ..........
# 2005-02-10 00:00:00
# Total portfolio value: 100758.67714999994  stock 1 number: 4456  stock 2 number: 1269  open cash32996.322749999956
# ..........
# 2005-02-11 00:00:00
# Total portfolio value: 101533.88914999994  stock 1 number: 4456  stock 2 number: 1269  open cash32960.54274999996
# ..........
# 2005-02-14 00:00:00
# Total portfolio value: 102789.44074999995  stock 1 number: 4456  stock 2 number: 1269  open cash32924.76274999996
# ..........
# 2005-02-15 00:00:00
# Total portfolio value: 103973.58074999996  stock 1 number: 4456  stock 2 number: 1269  open cash32888.73274999996
# ..........
# 2005-02-16 00:00:00
# Total portfolio value: 103818.48074999996  stock 1 number: 4456  stock 2 number: 1269  open cash32852.59274999996
# ..........
# 2005-02-17 00:00:00
# Total portfolio value: 103163.63074999995  stock 1 number: 4456  stock 2 number: 1269  open cash32816.932749999956
# ..........
# 2005-02-18 00:00:00
# Total portfolio value: 102360.98234999995  stock 1 number: 4456  stock 2 number: 1269  open cash32781.242749999954
# ..........
# 2005-02-22 00:00:00
# Total portfolio value: 101143.83914999996  stock 1 number: 4456  stock 2 number: 1269  open cash32745.932749999953
# ..........
# 2005-02-23 00:00:00
# Total portfolio value: 101210.82714999995  stock 1 number: 4456  stock 2 number: 1269  open cash32711.21274999995
# ..........
# 2005-02-24 00:00:00
# Total portfolio value: 102076.04834999995  stock 1 number: 4456  stock 2 number: 1269  open cash32677.072749999952
# ..........
# 2005-02-25 00:00:00
# Total portfolio value: 102432.75274999996  stock 1 number: 4456  stock 2 number: 1269  open cash32642.382749999953
# ..........
# 2005-02-28 00:00:00
# Total portfolio value: 102850.08714999996  stock 1 number: 4456  stock 2 number: 1269  open cash32607.39274999995
# ..........
# 2005-03-01 00:00:00
# Total portfolio value: 102875.52994999995  stock 1 number: 4456  stock 2 number: 1269  open cash32572.21274999995
# ..........
# 2005-03-02 00:00:00
# Total portfolio value: 102762.27714999995  stock 1 number: 4456  stock 2 number: 1269  open cash32536.822749999952
# ..........
# 2005-03-03 00:00:00
# Total portfolio value: 101588.79354999994  stock 1 number: 4456  stock 2 number: 1269  open cash32501.322749999952
# ..........
# 2005-03-04 00:00:00
# Total portfolio value: 102388.45154999995  stock 1 number: 4456  stock 2 number: 1269  open cash32465.67274999995
# ..........
# 2005-03-07 00:00:00
# Total portfolio value: 102914.72034999995  stock 1 number: 4456  stock 2 number: 1269  open cash32429.822749999952
# ..........
# 2005-03-08 00:00:00
# Total portfolio value: 100989.74954999995  stock 1 number: 4456  stock 2 number: 1269  open cash32393.502749999952
# ..........
# 2005-03-09 00:00:00
# Total portfolio value: 99734.50234999995  stock 1 number: 4456  stock 2 number: 1269  open cash32357.67274999995
# ..........
# 2005-03-10 00:00:00
# Total portfolio value: 99351.78194999995  stock 1 number: 4456  stock 2 number: 1269  open cash32322.27274999995
# ..........
# 2005-03-11 00:00:00
# Total portfolio value: 99366.04154999994  stock 1 number: 4456  stock 2 number: 1269  open cash32287.36274999995
# ..........
# 2005-03-14 00:00:00
# Total portfolio value: 99168.56874999995  stock 1 number: 4456  stock 2 number: 1269  open cash32252.61274999995
# ..........
# 2005-03-15 00:00:00
# Total portfolio value: 98965.48954999995  stock 1 number: 4456  stock 2 number: 1269  open cash32218.01274999995
# ..........
# 2005-03-16 00:00:00
# Total portfolio value: 98663.57874999996  stock 1 number: 4456  stock 2 number: 1269  open cash32183.83274999995
# ..........
# 2005-03-17 00:00:00
# Total portfolio value: 99367.52634999994  stock 1 number: 4456  stock 2 number: 1269  open cash32149.96274999995
# ..........
# 2005-03-18 00:00:00
# Total portfolio value: 99980.16234999994  stock 1 number: 4456  stock 2 number: 1269  open cash32115.99274999995
# ..........
# 2005-03-21 00:00:00
# Total portfolio value: 99746.17554999996  stock 1 number: 4456  stock 2 number: 1269  open cash32081.83274999995
# ..........
# 2005-03-22 00:00:00
# Total portfolio value: 98556.22714999996  stock 1 number: 4456  stock 2 number: 1269  open cash32048.162749999952
# ..........
# 2005-03-23 00:00:00
# Total portfolio value: 98401.62234999995  stock 1 number: 4456  stock 2 number: 1269  open cash32015.01274999995
# ..........
# 2005-03-24 00:00:00
# Total portfolio value: 97959.22394999996  stock 1 number: 4456  stock 2 number: 1269  open cash31981.83274999995
# ..........
# 2005-03-28 00:00:00
# Total portfolio value: 98590.91234999996  stock 1 number: 4456  stock 2 number: 1269  open cash31948.95274999995
# ..........
# 2005-03-29 00:00:00
# Total portfolio value: 98162.23674999995  stock 1 number: 4456  stock 2 number: 1269  open cash31915.56274999995
# ..........
# 2005-03-30 00:00:00
# Total portfolio value: 99857.54874999994  stock 1 number: 4456  stock 2 number: 1269  open cash31882.13274999995
# ..........
# 2005-03-31 00:00:00
# Total portfolio value: 99115.44114999996  stock 1 number: 4456  stock 2 number: 1269  open cash31847.81274999995
# ..........
# 2005-04-01 00:00:00
# Total portfolio value: 98306.52234999994  stock 1 number: 4456  stock 2 number: 1269  open cash31813.54274999995
# ..........
# 2005-04-04 00:00:00
# Total portfolio value: 99642.45034999996  stock 1 number: 4456  stock 2 number: 1269  open cash31779.53274999995
# ..........
# 2005-04-05 00:00:00
# Total portfolio value: 100419.06474999996  stock 1 number: 4456  stock 2 number: 1269  open cash31744.53274999995
# ..........
# 2005-04-06 00:00:00
# Total portfolio value: 100051.36314999996  stock 1 number: 4456  stock 2 number: 1269  open cash31709.252749999952
# ..........
# 2005-04-07 00:00:00
# Total portfolio value: 100818.99194999994  stock 1 number: 4456  stock 2 number: 1269  open cash31674.432749999953
# ..........
# 2005-04-08 00:00:00
# Total portfolio value: 100506.32554999995  stock 1 number: 4456  stock 2 number: 1269  open cash31639.53274999995
# ..........
# 2005-04-11 00:00:00
# Total portfolio value: 99433.92314999996  stock 1 number: 4456  stock 2 number: 1269  open cash31604.932749999953
# ..........
# 2005-04-12 00:00:00
# Total portfolio value: 99859.82194999995  stock 1 number: 4456  stock 2 number: 1269  open cash31570.332749999954
# ..........
# 2005-04-13 00:00:00
# Total portfolio value: 98481.35634999994  stock 1 number: 4456  stock 2 number: 1269  open cash31535.702749999953
# ..........
# 2005-04-14 00:00:00
# Total portfolio value: 95872.02794999996  stock 1 number: 4456  stock 2 number: 1269  open cash31501.402749999954
# ..........
# 2005-04-15 00:00:00
# Total portfolio value: 93542.57034999995  stock 1 number: 4456  stock 2 number: 1269  open cash31467.432749999953
# ..........
# 2005-04-18 00:00:00
# Total portfolio value: 93637.45674999995  stock 1 number: 4456  stock 2 number: 1269  open cash31434.412749999952
# ..........
# 2005-04-19 00:00:00
# Total portfolio value: 94163.89594999995  stock 1 number: 4456  stock 2 number: 1269  open cash31401.412749999952
# ..........
# 2005-04-20 00:00:00
# Total portfolio value: 93826.98834999994  stock 1 number: 4456  stock 2 number: 1269  open cash31368.632749999953
# ..........
# 2005-04-21 00:00:00
# Total portfolio value: 95355.99674999995  stock 1 number: 4456  stock 2 number: 1269  open cash31335.382749999953
# ..........
# 2005-04-22 00:00:00
# Total portfolio value: 93487.27994999995  stock 1 number: 4456  stock 2 number: 1269  open cash31301.652749999954
# ..........
# 2005-04-25 00:00:00
# Total portfolio value: 94920.90754999996  stock 1 number: 4456  stock 2 number: 1269  open cash31268.612749999953
# ..........
# 2005-04-26 00:00:00
# Total portfolio value: 93395.40474999996  stock 1 number: 4456  stock 2 number: 1269  open cash31235.082749999954
# ..........
# 2005-04-27 00:00:00
# Total portfolio value: 91969.58554999995  stock 1 number: 4456  stock 2 number: 1269  open cash31202.372749999955
# ..........
# 2005-04-28 00:00:00
# Total portfolio value: 92719.12554999995  stock 1 number: 4456  stock 2 number: 1269  open cash31170.652749999954
# ..........
# 2005-04-29 00:00:00
# Total portfolio value: 92779.44394999996  stock 1 number: 4456  stock 2 number: 1269  open cash31138.132749999953
# ..........
# 2005-05-02 00:00:00
# Total portfolio value: 93898.24954999995  stock 1 number: 4456  stock 2 number: 1269  open cash31105.772749999953
# ..........
# 2005-05-03 00:00:00
# Total portfolio value: 93878.63474999995  stock 1 number: 4456  stock 2 number: 1269  open cash31072.672749999954
# ..........
# 2005-05-04 00:00:00
# Total portfolio value: 95334.12274999995  stock 1 number: 4456  stock 2 number: 1269  open cash31039.462749999955
# ..........
# 2005-05-05 00:00:00
# Total portfolio value: 95031.46594999995  stock 1 number: 4456  stock 2 number: 1269  open cash31005.502749999956
# ..........
# 2005-05-06 00:00:00
# Total portfolio value: 96028.53234999996  stock 1 number: 4456  stock 2 number: 1269  open cash30971.542749999957
# ..........
# 2005-05-09 00:00:00
# Total portfolio value: 95991.66914999996  stock 1 number: 4456  stock 2 number: 1269  open cash30937.022749999956
# --------------------------------
# Total Profit: $85957.03
# Total No. of days played: 499  out of overall days:  500
# Total portfolio value: 95957.02914999996  stock 1 number: 4456  stock 2 number: 1269  open cash30902.382749999957
# --------------------------------
